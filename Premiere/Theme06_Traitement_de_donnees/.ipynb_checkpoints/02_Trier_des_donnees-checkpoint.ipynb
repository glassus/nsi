# %% [markdown]
# # Trier des données

# %% [markdown]
# Nous reprenons notre fichier de joueurs de rugby du Top14.

# %%
import csv
f = open('data/top14.csv', "r", encoding = 'utf-8')
donnees = csv.DictReader(f)
joueurs = []
for ligne in donnees:
    joueurs.append(dict(ligne))
    
f.close()

# %% [markdown]
# ### Créer une fonction filtre
# L'objectif est de créer une fonction `joueursEquipe(equipe)` qui renvoie une liste contentant tous les joueurs de l'équipe `equipe`.
# Le paramètre `equipe` sera donnée sous forme de chaîne de caractères.
# La valeur renvoyée sera de type liste.

# %%
def joueursEquipe(equipe):
    ret = []
    
    for k in joueurs :
        if k['Equipe'] == equipe :
            ret.append(k)
    
    return ret

# %% [markdown]
# Exemple d'utilisation :

# %%
joueursEquipe("Bordeaux")
# Out:
# [{'Equipe': 'Bordeaux',
#   'Nom': 'Jefferson POIROT',
#   'Poste': 'Pilier',
#   'Date de naissance': '01/11/1992',
#   'Taille': '181',
#   'Poids': '117'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Lasha TABIDZE',
#   'Poste': 'Pilier',
#   'Date de naissance': '04/07/1997',
#   'Taille': '185',
#   'Poids': '117'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Laurent DELBOULBÈS',
#   'Poste': 'Pilier',
#   'Date de naissance': '17/11/1986',
#   'Taille': '181',
#   'Poids': '106'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Lekso KAULASHVILI',
#   'Poste': 'Pilier',
#   'Date de naissance': '27/08/1992',
#   'Taille': '187',
#   'Poids': '120'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Peni RAVAI',
#   'Poste': 'Pilier',
#   'Date de naissance': '16/06/1990',
#   'Taille': '185',
#   'Poids': '119'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Thierry PAÏVA',
#   'Poste': 'Pilier',
#   'Date de naissance': '19/11/1995',
#   'Taille': '184',
#   'Poids': '125'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Vadim COBILAS',
#   'Poste': 'Pilier',
#   'Date de naissance': '30/07/1983',
#   'Taille': '180',
#   'Poids': '118'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Adrien PÉLISSIÉ',
#   'Poste': 'Talonneur',
#   'Date de naissance': '07/08/1990',
#   'Taille': '181',
#   'Poids': '110'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Clément MAYNADIER',
#   'Poste': 'Talonneur',
#   'Date de naissance': '11/10/1988',
#   'Taille': '187',
#   'Poids': '100'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Alexandre FLANQUART',
#   'Poste': '2ème ligne',
#   'Date de naissance': '09/10/1989',
#   'Taille': '204',
#   'Poids': '120'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Cyril CAZEAUX',
#   'Poste': '2ème ligne',
#   'Date de naissance': '10/02/1995',
#   'Taille': '198',
#   'Poids': '113'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Jandré MARAIS',
#   'Poste': '2ème ligne',
#   'Date de naissance': '14/06/1989',
#   'Taille': '198',
#   'Poids': '118'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Kane DOUGLAS',
#   'Poste': '2ème ligne',
#   'Date de naissance': '01/06/1989',
#   'Taille': '202',
#   'Poids': '123'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Masalosalo TUTAIA',
#   'Poste': '2ème ligne',
#   'Date de naissance': '05/06/1984',
#   'Taille': '204',
#   'Poids': '125'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Afa AMOSA',
#   'Poste': '3ème ligne',
#   'Date de naissance': '11/10/1990',
#   'Taille': '187',
#   'Poids': '112'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Alexandre ROUMAT',
#   'Poste': '3ème ligne',
#   'Date de naissance': '27/06/1997',
#   'Taille': '198',
#   'Poids': '104'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Béka GORGADZE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '08/02/1996',
#   'Taille': '189',
#   'Poids': '105'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Cameron WOKI',
#   'Poste': '3ème ligne',
#   'Date de naissance': '07/11/1998',
#   'Taille': '196',
#   'Poids': '103'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Mahamadou DIABY',
#   'Poste': '3ème ligne',
#   'Date de naissance': '15/08/1990',
#   'Taille': '188',
#   'Poids': '105'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Marco TAULEIGNE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '30/08/1993',
#   'Taille': '191',
#   'Poids': '115'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Scott HIGGINBOTHAM',
#   'Poste': '3ème ligne',
#   'Date de naissance': '05/09/1986',
#   'Taille': '195',
#   'Poids': '110'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Maxime LUCU',
#   'Poste': 'Mêlée',
#   'Date de naissance': '12/01/1993',
#   'Taille': '177',
#   'Poids': '79'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Yann LESGOURGUES',
#   'Poste': 'Mêlée',
#   'Date de naissance': '17/01/1991',
#   'Taille': '174',
#   'Poids': '71'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Ben BOTICA',
#   'Poste': 'Ouverture',
#   'Date de naissance': '07/10/1989',
#   'Taille': '178',
#   'Poids': '93'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Lucas MÉRET',
#   'Poste': 'Ouverture',
#   'Date de naissance': '30/01/1995',
#   'Taille': '178',
#   'Poids': '85'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Matthieu JALIBERT',
#   'Poste': 'Ouverture',
#   'Date de naissance': '06/11/1998',
#   'Taille': '180',
#   'Poids': '79'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Jean-Baptiste DUBIÉ',
#   'Poste': 'Centre',
#   'Date de naissance': '16/07/1989',
#   'Taille': '181',
#   'Poids': '85'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Rémi LAMERAT',
#   'Poste': 'Centre',
#   'Date de naissance': '14/01/1990',
#   'Taille': '184',
#   'Poids': '105'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Semi RADRADRA',
#   'Poste': 'Centre',
#   'Date de naissance': '13/06/1992',
#   'Taille': '188',
#   'Poids': '102'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Seta TAMANIVALU',
#   'Poste': 'Centre',
#   'Date de naissance': '23/07/1992',
#   'Taille': '189',
#   'Poids': '110'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Ulupano SEUTENI',
#   'Poste': 'Centre',
#   'Date de naissance': '09/12/1993',
#   'Taille': '185',
#   'Poids': '95'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Blair CONNOR',
#   'Poste': 'Ailier',
#   'Date de naissance': '29/09/1988',
#   'Taille': '183',
#   'Poids': '82'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Nicolas PLAZY',
#   'Poste': 'Ailier',
#   'Date de naissance': '17/05/1994',
#   'Taille': '188',
#   'Poids': '85'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Santiago CORDERO',
#   'Poste': 'Ailier',
#   'Date de naissance': '06/12/1993',
#   'Taille': '177',
#   'Poids': '83'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Geoffrey CROS',
#   'Poste': 'Arrière',
#   'Date de naissance': '08/03/1997',
#   'Taille': '185',
#   'Poids': '85'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Nans DUCUING',
#   'Poste': 'Arrière',
#   'Date de naissance': '06/11/1991',
#   'Taille': '181',
#   'Poids': '90'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Romain BUROS',
#   'Poste': 'Arrière',
#   'Date de naissance': '31/07/1997',
#   'Taille': '187',
#   'Poids': '91'}]

# %% [markdown]
# Définir de la même manière une fonction `joueursPoste(poste)`.

# %% [markdown]
# ## Utilisation d'une fonction de tri

# %% [markdown]
# Comment classer les joueurs suivant leur taille ?
# La fonction `sorted(liste)` est efficace sur les listes : elle renvoie une nouvelle liste triée dans l'ordre croissant.

# %%
mylist = [4,2,8,6]
mynewlist = sorted(mylist)
print(mynewlist)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# Mais comment trier un dictionnaire ?

# %%
test = sorted(joueurs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-de081d14a3da> in <module>
# ----> 1 test = sorted(joueurs)
#
# TypeError: '<' not supported between instances of 'dict' and 'dict'

# %% [markdown]
# Il est normal que cette tentative échoue : un dictionnaire possède plusieurs clés différentes.
# Ici, plusieurs clés peuvent être des critères de tri : la taille, le poids.

# %% [markdown]
# ### un exemple de tri de dictionnaire

# %%
Simpsons = [{"Prenom" : "Bart", "age estimé": "10"},
           {"Prenom" : "Lisa", "age estimé": "8"},
           {"Prenom" : "Maggie", "age estimé": "1"},
           {"Prenom" : "Homer", "age estimé": "38"},
           {"Prenom" : "Marge", "age estimé": "37"}]

# %%
def age(personnage):
    return int(personnage["age estimé"])

# %%
age(Simpsons[0])
# Out:
# 10

# %% [markdown]
# La création de cette fonction `age()` va nous permettre de spécifier une clé de tri, par le paramètre `key` :

# %%
triSimpsons = sorted(Simpsons, key = age)

# %%
triSimpsons
# Out:
# [{'Prenom': 'Maggie', 'age estimé': '1'},
#  {'Prenom': 'Lisa', 'age estimé': '8'},
#  {'Prenom': 'Bart', 'age estimé': '10'},
#  {'Prenom': 'Marge', 'age estimé': '37'},
#  {'Prenom': 'Homer', 'age estimé': '38'}]

# %%
triSimpsons = sorted(Simpsons, key = age, reverse = True)

# %%
triSimpsons
# Out:
# [{'Prenom': 'Homer', 'age estimé': '38'},
#  {'Prenom': 'Marge', 'age estimé': '37'},
#  {'Prenom': 'Bart', 'age estimé': '10'},
#  {'Prenom': 'Lisa', 'age estimé': '8'},
#  {'Prenom': 'Maggie', 'age estimé': '1'}]

# %% [markdown]
# ## Exercice
# 1. Trier les joueurs du top14 par taille.
# 2. Trier les joueurs de Bordeaux par taille.
# 3. Trier les joueurs de Bordeaux suivant leur Indice de Masse Corporelle ([IMC](https://fr.wikipedia.org/wiki/Indice_de_masse_corporelle) )

# %%
def taillePlayer(player) :
    return int(player['Taille'])

# %%
joueurs_taille_croissant = sorted(joueurs, key = taillePlayer)
print(joueurs_taille_croissant)
# Out:
# [{'Equipe': 'Clermont', 'Nom': 'Rudy PAIGE', 'Poste': 'Mêlée', 'Date de naissance': '02/08/1989', 'Taille': '169', 'Poids': '77'}, {'Equipe': 'Bayonne', 'Nom': 'Guillaume ROUET', 'Poste': 'Mêlée', 'Date de naissance': '13/08/1988', 'Taille': '170', 'Poids': '75'}, {'Equipe': 'La Rochelle', 'Nom': 'Marc ANDREU', 'Poste': 'Ailier', 'Date de naissance': '27/12/1985', 'Taille': '170', 'Poids': '75'}, {'Equipe': 'Racing92', 'Nom': 'Teddy IRIBAREN', 'Poste': 'Mêlée', 'Date de naissance': '25/09/1990', 'Taille': '170', 'Poids': '70'}, {'Equipe': 'Brive', 'Nom': 'Quentin DELORD', 'Poste': 'Mêlée', 'Date de naissance': '10/02/1999', 'Taille': '171', 'Poids': '74'}, {'Equipe': 'La Rochelle', 'Nom': 'Gabriel LACROIX', 'Poste': 'Ailier', 'Date de naissance': '19/10/1993', 'Taille': '171', 'Poids': '80'}, {'Equipe': 'Toulouse', 'Nom': 'Cheslin KOLBE', 'Poste': 'Ailier', 'Date de naissance': '28/10/1993', 'Taille': '171', 'Poids': '80'}, {'Equipe': 'Montpellier', 'Nom': 'Benoît PAILLAUGUE', 'Poste': 'Mêlée', 'Date de naissance': '17/11/1987', 'Taille': '172', 'Poids': '74'}, {'Equipe': 'Paris', 'Nom': 'James HALL', 'Poste': 'Mêlée', 'Date de naissance': '02/01/1996', 'Taille': '172', 'Poids': '84'}, {'Equipe': 'Toulon', 'Nom': 'Gervais CORDIN', 'Poste': 'Arrière', 'Date de naissance': '10/12/1998', 'Taille': '172', 'Poids': '73'}, {'Equipe': 'Toulouse', 'Nom': 'Takeshi HINO', 'Poste': 'Talonneur', 'Date de naissance': '20/01/1990', 'Taille': '172', 'Poids': '100'}, {'Equipe': 'Clermont', 'Nom': 'Charlie CASSANG', 'Poste': 'Mêlée', 'Date de naissance': '08/02/1995', 'Taille': '173', 'Poids': '84'}, {'Equipe': 'La Rochelle', 'Nom': 'Arthur RETIÈRE', 'Poste': 'Ailier', 'Date de naissance': '01/08/1997', 'Taille': '173', 'Poids': '75'}, {'Equipe': 'Pau', 'Nom': 'Clovis LE BAIL', 'Poste': 'Mêlée', 'Date de naissance': '29/11/1995', 'Taille': '173', 'Poids': '74'}, {'Equipe': 'Agen', 'Nom': 'Marc BARTHOMEUF', 'Poste': 'Talonneur', 'Date de naissance': '19/07/1991', 'Taille': '174', 'Poids': '100'}, {'Equipe': 'Bayonne', 'Nom': 'Peyo MUSCARDITZ', 'Poste': 'Centre', 'Date de naissance': '02/01/1996', 'Taille': '174', 'Poids': '88'}, {'Equipe': 'Bordeaux', 'Nom': 'Yann LESGOURGUES', 'Poste': 'Mêlée', 'Date de naissance': '17/01/1991', 'Taille': '174', 'Poids': '71'}, {'Equipe': 'La Rochelle', 'Nom': 'Alexi BALÈS', 'Poste': 'Mêlée', 'Date de naissance': '30/05/1990', 'Taille': '174', 'Poids': '80'}, {'Equipe': 'Lyon', 'Nom': 'Jean-Marc DOUSSAIN', 'Poste': 'Ouverture', 'Date de naissance': '12/02/1991', 'Taille': '174', 'Poids': '88'}, {'Equipe': 'Montpellier', 'Nom': "Gabriel N'GANDEBE", 'Poste': 'Ailier', 'Date de naissance': '30/03/1997', 'Taille': '174', 'Poids': '75'}, {'Equipe': 'Racing92', 'Nom': 'Maxime MACHENAUD', 'Poste': 'Mêlée', 'Date de naissance': '30/12/1988', 'Taille': '174', 'Poids': '87'}, {'Equipe': 'Toulouse', 'Nom': 'Antoine DUPONT', 'Poste': 'Mêlée', 'Date de naissance': '15/11/1996', 'Taille': '174', 'Poids': '82'}, {'Equipe': 'Toulouse', 'Nom': 'Sébastien BÉZY', 'Poste': 'Mêlée', 'Date de naissance': '22/11/1991', 'Taille': '174', 'Poids': '74'}, {'Equipe': 'Bayonne', 'Nom': 'Torsten VAN JAARSVELD', 'Poste': 'Talonneur', 'Date de naissance': '30/06/1987', 'Taille': '175', 'Poids': '106'}, {'Equipe': 'Brive', 'Nom': 'Julien BLANC', 'Poste': 'Mêlée', 'Date de naissance': '04/10/1992', 'Taille': '175', 'Poids': '81'}, {'Equipe': 'Brive', 'Nom': 'Vasil LOBZHANIDZE', 'Poste': 'Mêlée', 'Date de naissance': '14/10/1996', 'Taille': '175', 'Poids': '75'}, {'Equipe': 'Clermont', 'Nom': 'Giorgi BERIA', 'Poste': 'Pilier', 'Date de naissance': '11/11/1999', 'Taille': '175', 'Poids': '107'}, {'Equipe': 'La Rochelle', 'Nom': 'Ihaia WEST', 'Poste': 'Ouverture', 'Date de naissance': '16/01/1992', 'Taille': '175', 'Poids': '85'}, {'Equipe': 'Lyon', 'Nom': 'Vivien DEVISME', 'Poste': 'Pilier', 'Date de naissance': '23/03/1992', 'Taille': '175', 'Poids': '112'}, {'Equipe': 'Pau', 'Nom': 'Lucas REY', 'Poste': 'Talonneur', 'Date de naissance': '27/04 ...

# %%
def IMC(player):
    masse = int(player['Poids'])
    taille_m = int(player['Taille']) / 100
    return masse / taille_m**2

# %%
IMC(joueurs[0])
# Out:
# 36.42987249544626

# %%
joueursUBB = [k for k in joueurs if k['Equipe'] == 'Bordeaux']

# %%
joueursUBB_tri = sorted(joueursUBB, key = IMC)

# %%
for k in joueursUBB_tri:
    print(k['Nom'], IMC(k))
# Out:
# Yann LESGOURGUES 23.450918219051392
# Nicolas PLAZY 24.049343594386603
# Matthieu JALIBERT 24.382716049382715
# Blair CONNOR 24.48565200513601
# Geoffrey CROS 24.835646457268076
# Maxime LUCU 25.2162533116282
# Jean-Baptiste DUBIÉ 25.94548395958609
# Romain BUROS 26.023048986244955
# Santiago CORDERO 26.493025631204315
# Alexandre ROUMAT 26.527905315784103
# Cameron WOKI 26.81174510620575
# Lucas MÉRET 26.82742078020452
# Nans DUCUING 27.471688898385274
# Ulupano SEUTENI 27.757487216946675
# Clément MAYNADIER 28.59675712774171
# Cyril CAZEAUX 28.823589429650035
# Alexandre FLANQUART 28.835063437139564
# Semi RADRADRA 28.85921231326392
# Scott HIGGINBOTHAM 28.928336620644316
# Ben BOTICA 29.352354500694357
# Béka GORGADZE 29.394473838918284
# Mahamadou DIABY 29.708012675418743
# Masalosalo TUTAIA 30.036524413687044
# Jandré MARAIS 30.09896949290889
# Kane DOUGLAS 30.144103519262817
# Seta TAMANIVALU 30.794210688390585
# Rémi LAMERAT 31.01370510396975
# Marco TAULEIGNE 31.523258682601902
# Afa AMOSA 32.028367983070716
# Laurent DELBOULBÈS 32.35554470254266
# Adrien PÉLISSIÉ 33.576508653582
# Lasha TABIDZE 34.18553688823959
# Lekso KAULASHVILI 34.31610855329005
# Peni RAVAI 34.76990504017531
# Jefferson POIROT 35.713195567900854
# Vadim COBILAS 36.41975308641975
# Thierry PAÏVA 36.92107750472589

# %% [markdown]
# ## Recherche des joueurs de profil  physique similaire

# %% [markdown]
# ### Distance entre deux joueurs
# Construire une fonction `distance(joueur1,joueur2)` qui renvoie la somme des carrés des différences de tailles et de poids entre les joueurs `joueur1` et `joueur2` :
# $$ d = (p_1-p_2)^2 + (t_1-t_2)^2$$

# %%
def distance(joueur1,joueur2):
    p1 = int(joueur1['Poids'])
    p2 = int(joueur2['Poids'])
    t1 = int(joueur1['Taille'])
    t2 = int(joueur2['Taille'])
    return (p1-p2)**2+(t1-t2)**2

# %% [markdown]
# ### Distance des joueurs avec Baptiste Serin

# %% [markdown]
# Retrouvons d'abord le numéro de Baptiste Serin dans notre classement de joueurs :

# %%
for k in range(len(joueurs)) :
    if joueurs[k]['Nom'] == 'Baptiste SERIN' :
        print(k)
# Out:
# 530

# %%
joueurs[530]
# Out:
# {'Equipe': 'Toulon',
#  'Nom': 'Baptiste SERIN',
#  'Poste': 'Mêlée',
#  'Date de naissance': '20/06/1994',
#  'Taille': '180',
#  'Poids': '79'}

# %% [markdown]
# Nous pouvons maintenant classer les joueurs suivant leur distance morphologique à Baptiste  SERIN :

# %%
def distanceSerin(joueur2):
    return distance(joueurs[530],joueur2)

# %%
distanceSerin(joueurs[530])
# Out:
# 0

# %%
joueurs_VS_Serin = sorted(joueurs, key = distanceSerin)

# %%
joueurs_VS_Serin
# Out:
# [{'Equipe': 'Bordeaux',
#   'Nom': 'Matthieu JALIBERT',
#   'Poste': 'Ouverture',
#   'Date de naissance': '06/11/1998',
#   'Taille': '180',
#   'Poids': '79'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Baptiste SERIN',
#   'Poste': 'Mêlée',
#   'Date de naissance': '20/06/1994',
#   'Taille': '180',
#   'Poids': '79'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Vincent RATTEZ',
#   'Poste': 'Arrière',
#   'Date de naissance': '24/03/1992',
#   'Taille': '180',
#   'Poids': '78'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Pierre PAGÈS',
#   'Poste': 'Mêlée',
#   'Date de naissance': '16/05/1990',
#   'Taille': '180',
#   'Poids': '78'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Tristan TEDDER',
#   'Poste': 'Ouverture',
#   'Date de naissance': '17/04/1996',
#   'Taille': '180',
#   'Poids': '80'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Morgan PARRA',
#   'Poste': 'Mêlée',
#   'Date de naissance': '15/11/1988',
#   'Taille': '180',
#   'Poids': '81'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Brandon FAJARDO',
#   'Poste': 'Ouverture',
#   'Date de naissance': '25/06/1994',
#   'Taille': '181',
#   'Poids': '77'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Johannes Petrus GRAAFF',
#   'Poste': 'Arrière',
#   'Date de naissance': '10/09/1989',
#   'Taille': '179',
#   'Poids': '77'},
#  {'Equipe': 'Castres',
#   'Nom': 'Martin LAVEAU',
#   'Poste': 'Ailier',
#   'Date de naissance': '10/09/1996',
#   'Taille': '182',
#   'Poids': '78'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Olivier KLEMENCZAK',
#   'Poste': 'Centre',
#   'Date de naissance': '01/06/1996',
#   'Taille': '181',
#   'Poids': '81'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Aymeric LUC',
#   'Poste': 'Arrière',
#   'Date de naissance': '14/10/1997',
#   'Taille': '180',
#   'Poids': '76'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Maxime LUCU',
#   'Poste': 'Mêlée',
#   'Date de naissance': '12/01/1993',
#   'Taille': '177',
#   'Poids': '79'},
#  {'Equipe': 'Pau',
#   'Nom': 'Thibault DAUBAGNA',
#   'Poste': 'Mêlée',
#   'Date de naissance': '20/05/1994',
#   'Taille': '177',
#   'Poids': '80'},
#  {'Equipe': 'Pau',
#   'Nom': 'Bastien POURAILLY',
#   'Poste': 'Ailier',
#   'Date de naissance': '31/01/1994',
#   'Taille': '177',
#   'Poids': '80'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Joaquin DIAZ BONILLA',
#   'Poste': 'Ouverture',
#   'Date de naissance': '12/04/1989',
#   'Taille': '177',
#   'Poids': '80'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Arthur BONNEVAL',
#   'Poste': 'Ailier',
#   'Date de naissance': '31/05/1995',
#   'Taille': '181',
#   'Poids': '82'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Werner KOK',
#   'Poste': 'Ailier',
#   'Date de naissance': '27/01/1993',
#   'Taille': '177',
#   'Poids': '78'},
#  {'Equipe': 'Agen',
#   'Nom': 'Valentin SAURS',
#   'Poste': 'Ailier',
#   'Date de naissance': '12/02/1995',
#   'Taille': '182',
#   'Poids': '82'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Julien TISSERON',
#   'Poste': 'Arrière',
#   'Date de naissance': '12/08/1995',
#   'Taille': '182',
#   'Poids': '82'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Anthony MÉRIC',
#   'Poste': 'Mêlée',
#   'Date de naissance': '15/02/1995',
#   'Taille': '177',
#   'Poids': '77'},
#  {'Equipe': 'Pau',
#   'Nom': 'Julien FUMAT',
#   'Poste': 'Centre',
#   'Date de naissance': '26/03/1987',
#   'Taille': '180',
#   'Poids': '83'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Greig LAIDLAW',
#   'Poste': 'Mêlée',
#   'Date de naissance': '12/10/1985',
#   'Taille': '176',
#   'Poids': '78'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Jonathan PÉLISSIÉ',
#   'Poste': 'Mêlée',
#   'Date de naissance': '06/06/1988',
#   'Taille': '179',
#   'Poids': '83'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Thomas DARMON',
#   'Poste': 'Ouverture',
#   'Date de naissance': '12/05/1998',
#   'Taille': '181',
#   'Poids': '83'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Blair CONNOR',
#   'Poste': 'Ailier',
#   'Date de naissance': '29/09/1988',
#   'Taille': '183',
#   'Poids': '82'},
#  {'Equipe': 'Castres',
#   'Nom': 'Thomas FORTUNEL',
#   'Poste': 'Ouverture',
#   'Date de naissance': '07/06/1995',
#   'Taille': '177',
#   'Poids': '76'},
#  {'Equipe': 'Pau',
#   'Nom': 'Samuel MARQUÈS',
#   'Poste': 'Mêlée',
#   'Date de naissance': '08/12/1988',
#   'Taille': '177',
#   'Poids': '76'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Antoine GIBERT',
#   'Poste': 'Mêlée',
#   'Date de naissance': '31/12/1997',
#   'Taille': '177',
#   'Poids': '76'},
#  {'Equipe': 'Agen',
#   'Nom': 'Benito MASILEVU',
#   'Poste': 'Ailier',
#   'Date de naissance': '07/10/1989',
#   'Taille': '178',
#   'Poids': '83'},
#  {'Equipe': 'Brive',
#   'Nom': 'Guillaume NAMY',
#   'Poste': 'Ailier',
#   'Date de naissance': '03/04/1989',
#   'Taille': '182',
#   'Poids': '83'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Nick ABENDANON',
#   'Poste': 'Arrière',
#   'Date de naissance': '27/08/1986',
#   'Taille': '178',
#   'Poids': '83'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Baptiste COUILLOUD',
#   'Poste': 'Mêlée',
#   'Date de naissance': '22/07/1997',
#   'Taille': '176',
#   'Poids': '77'},
#  {'Equipe': 'Paris',
#   'Nom': 'Arthur COVILLE',
#   'Poste': 'Mêlée',
#   'Date de naissance': '04/02/1998',
#   'Taille': '178',
#   'Poids': '83'},
#  {'Equipe': 'Agen',
#   'Nom': 'Hugo VERDU',
#   'Poste': 'Mêlée',
#   'Date de naissance': '24/10/1996',
#   'Taille': '176',
#   'Poids': '82'},
#  {'Equipe': 'Agen',
#   'Nom': 'Xavier CHAUVEAU',
#   'Poste': 'Mêlée',
#   'Date de naissance': '14/10/1992',
#   'Taille': '180',
#   'Poids': '84'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Santiago CORDERO',
#   'Poste': 'Ailier',
#   'Date de naissance': '06/12/1993',
#   'Taille': '177',
#   'Poids': '83'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Brice DULIN',
#   'Poste': 'Arrière',
#   'Date de naissance': '13/04/1990',
#   'Taille': '176',
#   'Poids': '82'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Louis SCHREUDER',
#   'Poste': 'Mêlée',
#   'Date de naissance': '25/04/1990',
#   'Taille': '184',
#   'Poids': '82'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Mathieu SMAÏLI',
#   'Poste': 'Ouverture',
#   'Date de naissance': '30/08/1999',
#   'Taille': '180',
#   'Poids': '84'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Emmanuel SAUBUSSE',
#   'Poste': 'Mêlée',
#   'Date de naissance': '23/11/1989',
#   'Taille': '181',
#   'Poids': '84'},
#  {'Equipe': 'Brive',
#   'Nom': 'Julien BLANC',
#   'Poste': 'Mêlée',
#   'Date de naissance': '04/10/1992',
#   'Taille': '175',
#   'Poids': '81'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Aaron CRUDEN',
#   'Poste': 'Ouverture',
#   'Date de naissance': '08/01/1989',
#   'Taille': '178',
#   'Poids': '84'},
#  {'Equipe': 'Paris',
#   'Nom': 'Kylan HAMDAOUI',
#   'Poste': 'Arrière',
#   'Date de naissance': '15/04/1994',
#   'Taille': '182',
#   'Poids': '84'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Enzo SANGA',
#   'Poste': 'Mêlée',
#   'Date de naissance': '19/05/1995',
#   'Taille': '176',
#   'Poids': '75'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Maxime LAFAGE',
#   'Poste': 'Ouverture',
#   'Date de naissance': '01/09/1994',
#   'Taille': '183',
#   'Poids': '84'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Sam HIDALGO-CLYNE',
#   'Poste': 'Mêlée',
#   'Date de naissance': '04/08/1993',
#   'Taille': '175',
#   'Poids': '76'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Jonathan WISNIEWSKI',
#   'Poste': 'Ouverture',
#   'Date de naissance': '16/07/1985',
#   'Taille': '180',
#   'Poids': '85'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Louis CARBONEL',
#   'Poste': 'Ouverture',
#   'Date de naissance': '04/02/1999',
#   'Taille': '180',
#   'Poids': '85'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Maxime MÉDARD',
#   'Poste': 'Arrière',
#   'Date de naissance': '16/11/1986',
#   'Taille': '180',
#   'Poids': '85'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Jean-Baptiste DUBIÉ',
#   'Poste': 'Centre',
#   'Date de naissance': '16/07/1989',
#   'Taille': '181',
#   'Poids': '85'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Alexi BALÈS',
#   'Poste': 'Mêlée',
#   'Date de naissance': '30/05/1990',
#   'Taille': '174',
#   'Poids': '80'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Lucas MÉRET',
#   'Poste': 'Ouverture',
#   'Date de naissance': '30/01/1995',
#   'Taille': '178',
#   'Poids': '85'},
#  {'Equipe': 'Brive',
#   'Nom': 'Vasil LOBZHANIDZE',
#   'Poste': 'Mêlée',
#   'Date de naissance': '14/10/1996',
#   'Taille': '175',
#   'Poids': '75'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Alexis PALISSON',
#   'Poste': 'Ailier',
#   'Date de naissance': '09/09/1987',
#   'Taille': '177',
#   'Poids': '85'},
#  {'Equipe': 'Paris',
#   'Nom': 'Nicolas SANCHEZ',
#   'Poste': 'Ouverture',
#   'Date de naissance': '26/10/1988',
#   'Taille': '177',
#   'Poids': '85'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Anthony BELLEAU',
#   'Poste': 'Ouverture',
#   'Date de naissance': '08/04/1996',
#   'Taille': '177',
#   'Poids': '85'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Antoine DUPONT',
#   'Poste': 'Mêlée',
#   'Date de naissance': '15/11/1996',
#   'Taille': '174',
#   'Poids': '82'},
#  {'Equipe': 'Pau',
#   'Nom': 'Antoine HASTOY',
#   'Poste': 'Ouverture',
#   'Date de naissance': '04/06/1997',
#   'Taille': '180',
#   'Poids': '86'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Arthur DUHAU',
#   'Poste': 'Ailier',
#   'Date de naissance': '09/08/1997',
#   'Taille': '181',
#   'Poids': '86'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Manuel ORDAS',
#   'Poste': 'Ouverture',
#   'Date de naissance': '21/02/1998',
#   'Taille': '186',
#   'Poids': '83'},
#  {'Equipe': 'Montpellier',
#   'Nom': "Gabriel N'GANDEBE",
#   'Poste': 'Ailier',
#   'Date de naissance': '30/03/1997',
#   'Taille': '174',
#   'Poids': '75'},
#  {'Equipe': 'Castres',
#   'Nom': 'Benjamin URDAPILLETA',
#   'Poste': 'Ouverture',
#   'Date de naissance': '11/03/1986',
#   'Taille': '178',
#   'Poids': '86'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Toby ARNOLD',
#   'Poste': 'Ailier',
#   'Date de naissance': '11/09/1987',
#   'Taille': '178',
#   'Poids': '86'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Anthony BOUTHIER',
#   'Poste': 'Arrière',
#   'Date de naissance': '19/06/1992',
#   'Taille': '182',
#   'Poids': '86'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Thomas RAMOS',
#   'Poste': 'Arrière',
#   'Date de naissance': '23/07/1995',
#   'Taille': '178',
#   'Poids': '86'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Louis DUPICHOT',
#   'Poste': 'Arrière',
#   'Date de naissance': '23/09/1995',
#   'Taille': '183',
#   'Poids': '86'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Geoffrey CROS',
#   'Poste': 'Arrière',
#   'Date de naissance': '08/03/1997',
#   'Taille': '185',
#   'Poids': '85'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Ihaia WEST',
#   'Poste': 'Ouverture',
#   'Date de naissance': '16/01/1992',
#   'Taille': '175',
#   'Poids': '85'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Sébastien BÉZY',
#   'Poste': 'Mêlée',
#   'Date de naissance': '22/11/1991',
#   'Taille': '174',
#   'Poids': '74'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Romain NTAMACK',
#   'Poste': 'Ouverture',
#   'Date de naissance': '01/05/1999',
#   'Taille': '186',
#   'Poids': '84'},
#  {'Equipe': 'Brive',
#   'Nom': 'Stuart OLDING',
#   'Poste': 'Centre',
#   'Date de naissance': '11/03/1993',
#   'Taille': '180',
#   'Poids': '87'},
#  {'Equipe': 'Paris',
#   'Nom': 'Clément DAGUIN',
#   'Poste': 'Mêlée',
#   'Date de naissance': '25/05/1992',
#   'Taille': '180',
#   'Poids': '87'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Gabin VILLIÈRE',
#   'Poste': 'Ailier',
#   'Date de naissance': '13/12/1995',
#   'Taille': '180',
#   'Poids': '87'},
#  {'Equipe': 'Castres',
#   'Nom': 'Benjamin LAPEYRE',
#   'Poste': 'Ailier',
#   'Date de naissance': '24/09/1986',
#   'Taille': '181',
#   'Poids': '87'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Arthur RETIÈRE',
#   'Poste': 'Ailier',
#   'Date de naissance': '01/08/1997',
#   'Taille': '173',
#   'Poids': '75'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Clément LAPORTE',
#   'Poste': 'Arrière',
#   'Date de naissance': '07/01/1998',
#   'Taille': '181',
#   'Poids': '87'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Finn RUSSELL',
#   'Poste': 'Ouverture',
#   'Date de naissance': '23/09/1992',
#   'Taille': '183',
#   'Poids': '87'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Charlie CASSANG',
#   'Poste': 'Mêlée',
#   'Date de naissance': '08/02/1995',
#   'Taille': '173',
#   'Poids': '84'},
#  {'Equipe': 'Pau',
#   'Nom': 'Clovis LE BAIL',
#   'Poste': 'Mêlée',
#   'Date de naissance': '29/11/1995',
#   'Taille': '173',
#   'Poids': '74'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Camille LOPEZ',
#   'Poste': 'Ouverture',
#   'Date de naissance': '03/04/1989',
#   'Taille': '176',
#   'Poids': '87'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Jules FAVRE',
#   'Poste': 'Centre',
#   'Date de naissance': '22/03/1999',
#   'Taille': '181',
#   'Poids': '88'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Gabriel LACROIX',
#   'Poste': 'Ailier',
#   'Date de naissance': '19/10/1993',
#   'Taille': '171',
#   'Poids': '80'},
#  {'Equipe': 'Paris',
#   'Nom': 'Adrien LAPÈGUE',
#   'Poste': 'Ailier',
#   'Date de naissance': '21/10/1998',
#   'Taille': '181',
#   'Poids': '88'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Cheslin KOLBE',
#   'Poste': 'Ailier',
#   'Date de naissance': '28/10/1993',
#   'Taille': '171',
#   'Poids': '80'},
#  {'Equipe': 'Castres',
#   'Nom': 'Julien CAMINATI',
#   'Poste': 'Ailier',
#   'Date de naissance': '28/10/1985',
#   'Taille': '178',
#   'Poids': '88'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Benoît PAILLAUGUE',
#   'Poste': 'Mêlée',
#   'Date de naissance': '17/11/1987',
#   'Taille': '172',
#   'Poids': '74'},
#  {'Equipe': 'Paris',
#   'Nom': 'James HALL',
#   'Poste': 'Mêlée',
#   'Date de naissance': '02/01/1996',
#   'Taille': '172',
#   'Poids': '84'},
#  {'Equipe': 'Pau',
#   'Nom': 'Charly MALIÉ',
#   'Poste': 'Arrière',
#   'Date de naissance': '05/11/1991',
#   'Taille': '185',
#   'Poids': '87'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Jake MCINTYRE',
#   'Poste': 'Ouverture',
#   'Date de naissance': '28/04/1994',
#   'Taille': '177',
#   'Poids': '88'},
#  {'Equipe': 'Agen',
#   'Nom': 'Paul ABADIE',
#   'Poste': 'Mêlée',
#   'Date de naissance': '28/07/1994',
#   'Taille': '176',
#   'Poids': '88'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Jérémy SINZELLE',
#   'Poste': 'Centre',
#   'Date de naissance': '02/07/1990',
#   'Taille': '184',
#   'Poids': '88'},
#  {'Equipe': 'Paris',
#   'Nom': 'Jules PLISSON',
#   'Poste': 'Ouverture',
#   'Date de naissance': '20/08/1991',
#   'Taille': '184',
#   'Poids': '88'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Yann LESGOURGUES',
#   'Poste': 'Mêlée',
#   'Date de naissance': '17/01/1991',
#   'Taille': '174',
#   'Poids': '71'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Nicolas PLAZY',
#   'Poste': 'Ailier',
#   'Date de naissance': '17/05/1994',
#   'Taille': '188',
#   'Poids': '85'},
#  {'Equipe': 'Brive',
#   'Nom': 'Nico LEE',
#   'Poste': 'Centre',
#   'Date de naissance': '13/03/1994',
#   'Taille': '180',
#   'Poids': '89'},
#  {'Equipe': 'Castres',
#   'Nom': 'Robert EBERSOHN',
#   'Poste': 'Centre',
#   'Date de naissance': '23/02/1989',
#   'Taille': '180',
#   'Poids': '89'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Maxime MACHENAUD',
#   'Poste': 'Mêlée',
#   'Date de naissance': '30/12/1988',
#   'Taille': '174',
#   'Poids': '87'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Gervais CORDIN',
#   'Poste': 'Arrière',
#   'Date de naissance': '10/12/1998',
#   'Taille': '172',
#   'Poids': '73'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Brock JAMES',
#   'Poste': 'Ouverture',
#   'Date de naissance': '22/10/1981',
#   'Taille': '179',
#   'Poids': '89'},
#  {'Equipe': 'Brive',
#   'Nom': 'Franck ROMANET',
#   'Poste': 'Ailier',
#   'Date de naissance': '02/05/1986',
#   'Taille': '178',
#   'Poids': '89'},
#  {'Equipe': 'Paris',
#   'Nom': 'Julien ARIAS',
#   'Poste': 'Ailier',
#   'Date de naissance': '26/10/1983',
#   'Taille': '178',
#   'Poids': '89'},
#  {'Equipe': 'Brive',
#   'Nom': 'Quentin DELORD',
#   'Poste': 'Mêlée',
#   'Date de naissance': '10/02/1999',
#   'Taille': '171',
#   'Poids': '74'},
#  {'Equipe': 'Castres',
#   'Nom': 'Florian VIALELLE',
#   'Poste': 'Centre',
#   'Date de naissance': '05/10/1993',
#   'Taille': '185',
#   'Poids': '88'},
#  {'Equipe': 'Brive',
#   'Nom': 'Enzo HERVÉ',
#   'Poste': 'Ouverture',
#   'Date de naissance': '13/10/1998',
#   'Taille': '177',
#   'Poids': '89'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Guillaume ROUET',
#   'Poste': 'Mêlée',
#   'Date de naissance': '13/08/1988',
#   'Taille': '170',
#   'Poids': '75'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Marc ANDREU',
#   'Poste': 'Ailier',
#   'Date de naissance': '27/12/1985',
#   'Taille': '170',
#   'Poids': '75'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Johan GOOSEN',
#   'Poste': 'Arrière',
#   'Date de naissance': '27/07/1992',
#   'Taille': '184',
#   'Poids': '89'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Peyo MUSCARDITZ',
#   'Poste': 'Centre',
#   'Date de naissance': '02/01/1996',
#   'Taille': '174',
#   'Poids': '88'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Jean-Marc DOUSSAIN',
#   'Poste': 'Ouverture',
#   'Date de naissance': '12/02/1991',
#   'Taille': '174',
#   'Poids': '88'},
#  {'Equipe': 'Agen',
#   'Nom': 'JJ TAULAGI',
#   'Poste': 'Arrière',
#   'Date de naissance': '18/06/1993',
#   'Taille': '180',
#   'Poids': '90'},
#  {'Equipe': 'Brive',
#   'Nom': 'Arnaud MIGNARDI',
#   'Poste': 'Centre',
#   'Date de naissance': '01/11/1986',
#   'Taille': '180',
#   'Poids': '90'},
#  {'Equipe': 'Paris',
#   'Nom': 'Alex ARRATE',
#   'Poste': 'Centre',
#   'Date de naissance': '24/06/1997',
#   'Taille': '180',
#   'Poids': '90'},
#  {'Equipe': 'Paris',
#   'Nom': 'Lester ETIEN',
#   'Poste': 'Ailier',
#   'Date de naissance': '21/06/1995',
#   'Taille': '180',
#   'Poids': '90'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Sean ROBINSON',
#   'Poste': 'Ailier',
#   'Date de naissance': '02/11/1993',
#   'Taille': '181',
#   'Poids': '90'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Nans DUCUING',
#   'Poste': 'Arrière',
#   'Date de naissance': '06/11/1991',
#   'Taille': '181',
#   'Poids': '90'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Julien HÉRITEAU',
#   'Poste': 'Centre',
#   'Date de naissance': '12/09/1994',
#   'Taille': '181',
#   'Poids': '90'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Rudy PAIGE',
#   'Poste': 'Mêlée',
#   'Date de naissance': '02/08/1989',
#   'Taille': '169',
#   'Poids': '77'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Tim NANAI-WILLIAMS',
#   'Poste': 'Ailier',
#   'Date de naissance': '12/06/1989',
#   'Taille': '182',
#   'Poids': '90'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Rudi WULF',
#   'Poste': 'Centre',
#   'Date de naissance': '02/02/1984',
#   'Taille': '182',
#   'Poids': '90'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Nehe MILNER-SKUDDER',
#   'Poste': 'Arrière',
#   'Date de naissance': '15/12/1990',
#   'Taille': '182',
#   'Poids': '90'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Djibril CAMARA',
#   'Poste': 'Ailier',
#   'Date de naissance': '22/06/1989',
#   'Taille': '183',
#   'Poids': '90'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Arthur VINCENT',
#   'Poste': 'Centre',
#   'Date de naissance': '30/09/1999',
#   'Taille': '183',
#   'Poids': '90'},
#  {'Equipe': 'Pau',
#   'Nom': 'Colin SLADE',
#   'Poste': 'Ouverture',
#   'Date de naissance': '10/10/1987',
#   'Taille': '183',
#   'Poids': '90'},
#  {'Equipe': 'Pau',
#   'Nom': 'Tom TAYLOR',
#   'Poste': 'Ouverture',
#   'Date de naissance': '11/03/1989',
#   'Taille': '183',
#   'Poids': '90'},
#  {'Equipe': 'Brive',
#   'Nom': 'David DELARUE',
#   'Poste': 'Mêlée',
#   'Date de naissance': '27/10/1996',
#   'Taille': '190',
#   'Poids': '85'},
#  {'Equipe': 'Pau',
#   'Nom': 'Pierre NUENO',
#   'Poste': 'Centre',
#   'Date de naissance': '15/05/1996',
#   'Taille': '184',
#   'Poids': '90'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Josua TUISOVA',
#   'Poste': 'Ailier',
#   'Date de naissance': '04/02/1994',
#   'Taille': '180',
#   'Poids': '91'},
#  {'Equipe': 'Paris',
#   'Nom': 'Joris SEGONDS',
#   'Poste': 'Ouverture',
#   'Date de naissance': '06/04/1997',
#   'Taille': '180',
#   'Poids': '91'},
#  {'Equipe': 'Toulon',
#   'Nom': "Duncan PAIA'AUA",
#   'Poste': 'Centre',
#   'Date de naissance': '20/01/1995',
#   'Taille': '180',
#   'Poids': '91'},
#  {'Equipe': 'Agen',
#   'Nom': 'Loris TOLOT',
#   'Poste': 'Arrière',
#   'Date de naissance': '03/03/1993',
#   'Taille': '185',
#   'Poids': '90'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Juan IMHOFF',
#   'Poste': 'Ailier',
#   'Date de naissance': '11/05/1988',
#   'Taille': '185',
#   'Poids': '90'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Teddy THOMAS',
#   'Poste': 'Ailier',
#   'Date de naissance': '18/09/1993',
#   'Taille': '185',
#   'Poids': '90'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Hugo BONNEVAL',
#   'Poste': 'Arrière',
#   'Date de naissance': '19/11/1990',
#   'Taille': '185',
#   'Poids': '90'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Zack HOLMES',
#   'Poste': 'Ouverture',
#   'Date de naissance': '30/05/1990',
#   'Taille': '175',
#   'Poids': '90'},
#  {'Equipe': 'Paris',
#   'Nom': 'Morné STEYN',
#   'Poste': 'Ouverture',
#   'Date de naissance': '11/07/1984',
#   'Taille': '183',
#   'Poids': '91'},
#  {'Equipe': 'Brive',
#   'Nom': 'Thomas LARANJEIRA',
#   'Poste': 'Ouverture',
#   'Date de naissance': '05/05/1992',
#   'Taille': '186',
#   'Poids': '90'},
#  {'Equipe': 'Racing92',
#   'Nom': 'François TRINH-DUC',
#   'Poste': 'Ouverture',
#   'Date de naissance': '11/11/1986',
#   'Taille': '186',
#   'Poids': '90'},
#  {'Equipe': 'Castres',
#   'Nom': 'Rory KOCKOTT',
#   'Poste': 'Mêlée',
#   'Date de naissance': '25/06/1986',
#   'Taille': '180',
#   'Poids': '92'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Léonard PARIS',
#   'Poste': 'Centre',
#   'Date de naissance': '20/03/1996',
#   'Taille': '180',
#   'Poids': '92'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Matthis LEBEL',
#   'Poste': 'Arrière',
#   'Date de naissance': '25/03/1999',
#   'Taille': '185',
#   'Poids': '91'},
#  {'Equipe': 'Pau',
#   'Nom': 'Jesse MOGG',
#   'Poste': 'Arrière',
#   'Date de naissance': '08/06/1989',
#   'Taille': '187',
#   'Poids': '90'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Henry CHAVANCY',
#   'Poste': 'Centre',
#   'Date de naissance': '22/05/1988',
#   'Taille': '181',
#   'Poids': '92'},
#  {'Equipe': 'Agen',
#   'Nom': 'Raphaël LAGARDE',
#   'Poste': 'Ouverture',
#   'Date de naissance': '30/10/1988',
#   'Taille': '182',
#   'Poids': '92'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Yvan REILHAC',
#   'Poste': 'Centre',
#   'Date de naissance': '09/06/1995',
#   'Taille': '182',
#   'Poids': '92'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Teddy IRIBAREN',
#   'Poste': 'Mêlée',
#   'Date de naissance': '25/09/1990',
#   'Taille': '170',
#   'Poids': '70'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Théo DACHARY',
#   'Poste': 'Centre',
#   'Date de naissance': '26/03/1997',
#   'Taille': '184',
#   'Poids': '92'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Romain BUROS',
#   'Poste': 'Arrière',
#   'Date de naissance': '31/07/1997',
#   'Taille': '187',
#   'Poids': '91'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Tawera KERR-BARLOW',
#   'Poste': 'Mêlée',
#   'Date de naissance': '15/08/1990',
#   'Taille': '187',
#   'Poids': '91'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Daniel IKPEFAN',
#   'Poste': 'Ailier',
#   'Date de naissance': '18/10/1993',
#   'Taille': '185',
#   'Poids': '92'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Pierre AGUILLON',
#   'Poste': 'Centre',
#   'Date de naissance': '27/03/1987',
#   'Taille': '180',
#   'Poids': '93'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Maxime MERMOZ',
#   'Poste': 'Centre',
#   'Date de naissance': '28/07/1986',
#   'Taille': '181',
#   'Poids': '93'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Michael RURU',
#   'Poste': 'Mêlée',
#   'Date de naissance': '03/12/1990',
#   'Taille': '182',
#   'Poids': '93'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Ben BOTICA',
#   'Poste': 'Ouverture',
#   'Date de naissance': '07/10/1989',
#   'Taille': '178',
#   'Poids': '93'},
#  {'Equipe': 'Brive',
#   'Nom': 'Setareki BITUNIYATA',
#   'Poste': 'Ailier',
#   'Date de naissance': '12/08/1995',
#   'Taille': '190',
#   'Poids': '89'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Wesley FOFANA',
#   'Poste': 'Centre',
#   'Date de naissance': '20/01/1988',
#   'Taille': '182',
#   'Poids': '93'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Geoffrey DOUMAYROU',
#   'Poste': 'Centre',
#   'Date de naissance': '16/09/1989',
#   'Taille': '186',
#   'Poids': '92'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Rhys WEBB',
#   'Poste': 'Mêlée',
#   'Date de naissance': '09/12/1988',
#   'Taille': '183',
#   'Poids': '93'},
#  {'Equipe': 'Brive',
#   'Nom': 'Alban RAMETTE',
#   'Poste': 'Centre',
#   'Date de naissance': '07/10/1998',
#   'Taille': '188',
#   'Poids': '91'},
#  {'Equipe': 'Agen',
#   'Nom': 'Mathieu LAMOULIE',
#   'Poste': 'Arrière',
#   'Date de naissance': '07/08/1990',
#   'Taille': '184',
#   'Poids': '93'},
#  {'Equipe': 'Castres',
#   'Nom': 'Taylor PARIS',
#   'Poste': 'Ailier',
#   'Date de naissance': '06/10/1992',
#   'Taille': '185',
#   'Poids': '93'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Vincent MARTIN',
#   'Poste': 'Centre',
#   'Date de naissance': '04/09/1992',
#   'Taille': '185',
#   'Poids': '93'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Setariki TUICUVU',
#   'Poste': 'Arrière',
#   'Date de naissance': '07/09/1995',
#   'Taille': '179',
#   'Poids': '94'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Benjamin FALL',
#   'Poste': 'Arrière',
#   'Date de naissance': '03/03/1989',
#   'Taille': '186',
#   'Poids': '93'},
#  {'Equipe': 'Castres',
#   'Nom': 'Armand BATLLE',
#   'Poste': 'Ailier',
#   'Date de naissance': '12/04/1987',
#   'Taille': '188',
#   'Poids': '92'},
#  {'Equipe': 'Castres',
#   'Nom': 'Thomas COMBEZOU',
#   'Poste': 'Centre',
#   'Date de naissance': '26/01/1987',
#   'Taille': '184',
#   'Poids': '94'},
#  {'Equipe': 'Pau',
#   'Nom': 'Vincent PINTO',
#   'Poste': 'Ailier',
#   'Date de naissance': '10/04/1999',
#   'Taille': '187',
#   'Poids': '93'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Malietoa HINGANO',
#   'Poste': 'Centre',
#   'Date de naissance': '27/01/1992',
#   'Taille': '180',
#   'Poids': '95'},
#  {'Equipe': 'Castres',
#   'Nom': 'Ludovic RADOSAVLJEVIC',
#   'Poste': 'Mêlée',
#   'Date de naissance': '17/08/1989',
#   'Taille': '180',
#   'Poids': '95'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Brieuc PLESSIS-COUILLAUD',
#   'Poste': 'Centre',
#   'Date de naissance': '19/03/1994',
#   'Taille': '180',
#   'Poids': '95'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Thibaut REGARD',
#   'Poste': 'Centre',
#   'Date de naissance': '06/08/1993',
#   'Taille': '180',
#   'Poids': '95'},
#  {'Equipe': 'Pau',
#   'Nom': 'Quentin LESPIAUCQ-BRETTES',
#   'Poste': 'Talonneur',
#   'Date de naissance': '16/02/1995',
#   'Taille': '180',
#   'Poids': '95'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Julien MARCHAND',
#   'Poste': 'Talonneur',
#   'Date de naissance': '10/05/1995',
#   'Taille': '181',
#   'Poids': '95'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Callum WILSON',
#   'Poste': 'Centre',
#   'Date de naissance': '28/10/1990',
#   'Taille': '182',
#   'Poids': '95'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Pierre-Louis BARASSI',
#   'Poste': 'Centre',
#   'Date de naissance': '22/04/1998',
#   'Taille': '188',
#   'Poids': '93'},
#  {'Equipe': 'Brive',
#   'Nom': 'Axel MULLER',
#   'Poste': 'Ailier',
#   'Date de naissance': '25/11/1993',
#   'Taille': '186',
#   'Poids': '94'},
#  {'Equipe': 'Pau',
#   'Nom': 'Ben SMITH',
#   'Poste': 'Ailier',
#   'Date de naissance': '01/06/1986',
#   'Taille': '186',
#   'Poids': '94'},
#  {'Equipe': 'Paris',
#   'Nom': 'Lionel MAPOE',
#   'Poste': 'Centre',
#   'Date de naissance': '13/07/1988',
#   'Taille': '183',
#   'Poids': '95'},
#  {'Equipe': 'Pau',
#   'Nom': 'Florian NICOT',
#   'Poste': 'Centre',
#   'Date de naissance': '30/09/1986',
#   'Taille': '184',
#   'Poids': '95'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Samuel EZEALA',
#   'Poste': 'Ailier',
#   'Date de naissance': '11/12/1999',
#   'Taille': '187',
#   'Poids': '94'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Simon ZEBO',
#   'Poste': 'Ailier',
#   'Date de naissance': '16/03/1990',
#   'Taille': '187',
#   'Poids': '94'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Théo BELAN',
#   'Poste': 'Centre',
#   'Date de naissance': '15/11/1992',
#   'Taille': '187',
#   'Poids': '94'},
#  {'Equipe': 'Castres',
#   'Nom': 'Geoffrey PALIS',
#   'Poste': 'Arrière',
#   'Date de naissance': '08/07/1991',
#   'Taille': '189',
#   'Poids': '93'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Alofa ALOFA',
#   'Poste': 'Centre',
#   'Date de naissance': '12/03/1991',
#   'Taille': '185',
#   'Poids': '95'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Ulupano SEUTENI',
#   'Poste': 'Centre',
#   'Date de naissance': '09/12/1993',
#   'Taille': '185',
#   'Poids': '95'},
#  {'Equipe': 'Paris',
#   'Nom': 'Julien DELBOUIS',
#   'Poste': 'Centre',
#   'Date de naissance': '04/08/1999',
#   'Taille': '185',
#   'Poids': '95'},
#  {'Equipe': 'Pau',
#   'Nom': 'Lucas REY',
#   'Poste': 'Talonneur',
#   'Date de naissance': '27/04/1997',
#   'Taille': '175',
#   'Poids': '95'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Stéphane ONAMBÉLÉ',
#   'Poste': '3ème ligne',
#   'Date de naissance': '12/02/1993',
#   'Taille': '188',
#   'Poids': '94'},
#  {'Equipe': 'Brive',
#   'Nom': 'Rory SCHOLES',
#   'Poste': 'Ailier',
#   'Date de naissance': '23/04/1993',
#   'Taille': '186',
#   'Poids': '95'},
#  {'Equipe': 'Montpellier',
#   'Nom': "Kahn FOTUALI'I",
#   'Poste': 'Mêlée',
#   'Date de naissance': '22/05/1982',
#   'Taille': '183',
#   'Poids': '96'},
#  {'Equipe': 'Castres',
#   'Nom': 'Julien DUMORA',
#   'Poste': 'Arrière',
#   'Date de naissance': '24/03/1988',
#   'Taille': '184',
#   'Poids': '96'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Ben VOLAVOLA',
#   'Poste': 'Ouverture',
#   'Date de naissance': '13/01/1991',
#   'Taille': '191',
#   'Poids': '93'},
#  {'Equipe': 'Brive',
#   'Nom': 'Esteban ABADIE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '01/12/1997',
#   'Taille': '188',
#   'Poids': '95'},
#  {'Equipe': 'Clermont',
#   'Nom': 'JJ ENGELBRECHT',
#   'Poste': 'Centre',
#   'Date de naissance': '22/02/1989',
#   'Taille': '190',
#   'Poids': '94'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Noa NAKAITACI',
#   'Poste': 'Ailier',
#   'Date de naissance': '11/07/1990',
#   'Taille': '190',
#   'Poids': '94'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Jean-Marcellin BUTTIN',
#   'Poste': 'Arrière',
#   'Date de naissance': '16/12/1991',
#   'Taille': '190',
#   'Poids': '94'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Sofiane GUITOUNE',
#   'Poste': 'Ailier',
#   'Date de naissance': '27/03/1989',
#   'Taille': '186',
#   'Poids': '96'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Guillaume CRAMONT',
#   'Poste': 'Talonneur',
#   'Date de naissance': '29/12/2000',
#   'Taille': '182',
#   'Poids': '97'},
#  {'Equipe': 'Paris',
#   'Nom': 'Ruan COMBRINCK',
#   'Poste': 'Ailier',
#   'Date de naissance': '10/05/1990',
#   'Taille': '183',
#   'Poids': '97'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Eliott ROUDIL',
#   'Poste': 'Ailier',
#   'Date de naissance': '30/10/1996',
#   'Taille': '184',
#   'Poids': '97'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Kini MURIMURIVALU',
#   'Poste': 'Arrière',
#   'Date de naissance': '15/05/1989',
#   'Taille': '176',
#   'Poids': '97'},
#  {'Equipe': 'Agen',
#   'Nom': 'Johann SADIE',
#   'Poste': 'Centre',
#   'Date de naissance': '23/01/1989',
#   'Taille': '188',
#   'Poids': '96'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'François CROS',
#   'Poste': '3ème ligne',
#   'Date de naissance': '25/03/1994',
#   'Taille': '190',
#   'Poids': '95'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Romain BARTHÉLÉMY',
#   'Poste': 'Centre',
#   'Date de naissance': '25/01/1990',
#   'Taille': '186',
#   'Poids': '97'},
#  {'Equipe': 'Brive',
#   'Nom': 'Guillaume GALLETIER',
#   'Poste': 'Centre',
#   'Date de naissance': '07/03/1997',
#   'Taille': '178',
#   'Poids': '98'},
#  {'Equipe': 'Castres',
#   'Nom': 'Filipo NAKOSI',
#   'Poste': 'Ailier',
#   'Date de naissance': '08/04/1992',
#   'Taille': '182',
#   'Poids': '98'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Damian PENAUD',
#   'Poste': 'Ailier',
#   'Date de naissance': '25/09/1996',
#   'Taille': '192',
#   'Poids': '94'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Henry IMMELMAN',
#   'Poste': 'Arrière',
#   'Date de naissance': '26/05/1995',
#   'Taille': '189',
#   'Poids': '96'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Jan SERFONTEIN',
#   'Poste': 'Centre',
#   'Date de naissance': '15/04/1993',
#   'Taille': '187',
#   'Poids': '97'},
#  {'Equipe': 'Pau',
#   'Nom': 'Benson STANLEY',
#   'Poste': 'Centre',
#   'Date de naissance': '11/09/1984',
#   'Taille': '184',
#   'Poids': '98'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Virimi VAKATAWA',
#   'Poste': 'Centre',
#   'Date de naissance': '01/05/1992',
#   'Taille': '185',
#   'Poids': '98'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Pierre TOURNEBIZE',
#   'Poste': 'Ailier',
#   'Date de naissance': '25/09/1998',
#   'Taille': '186',
#   'Poids': '98'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Alivereti RAKA',
#   'Poste': 'Ailier',
#   'Date de naissance': '09/12/1994',
#   'Taille': '189',
#   'Poids': '97'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Pita AHKI',
#   'Poste': 'Centre',
#   'Date de naissance': '24/09/1992',
#   'Taille': '189',
#   'Poids': '97'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Jean MONRIBOT',
#   'Poste': '3ème ligne',
#   'Date de naissance': '11/10/1987',
#   'Taille': '183',
#   'Poids': '99'},
#  {'Equipe': 'Agen',
#   'Nom': 'Sam VAKA',
#   'Poste': 'Centre',
#   'Date de naissance': '26/10/1992',
#   'Taille': '187',
#   'Poids': '98'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Lucas TAUZIN',
#   'Poste': 'Ailier',
#   'Date de naissance': '21/05/1998',
#   'Taille': '187',
#   'Poids': '98'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Yoann HUGET',
#   'Poste': 'Ailier',
#   'Date de naissance': '02/06/1987',
#   'Taille': '190',
#   'Poids': '97'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Arnaud DUPUTS',
#   'Poste': '3ème ligne',
#   'Date de naissance': '26/07/1995',
#   'Taille': '188',
#   'Poids': '98'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Julien BARDY',
#   'Poste': '3ème ligne',
#   'Date de naissance': '03/04/1986',
#   'Taille': '188',
#   'Poids': '98'},
#  {'Equipe': 'Pau',
#   'Nom': 'Martin PUECH',
#   'Poste': '3ème ligne',
#   'Date de naissance': '14/12/1988',
#   'Taille': '193',
#   'Poids': '95'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Facundo BOSCH',
#   'Poste': 'Talonneur',
#   'Date de naissance': '08/08/1991',
#   'Taille': '180',
#   'Poids': '100'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Isaia TOEAVA',
#   'Poste': 'Arrière',
#   'Date de naissance': '15/01/1986',
#   'Taille': '181',
#   'Poids': '100'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Jérémie MAUROUARD',
#   'Poste': 'Talonneur',
#   'Date de naissance': '23/09/1992',
#   'Taille': '181',
#   'Poids': '100'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Youri DELHOMMEL',
#   'Poste': 'Talonneur',
#   'Date de naissance': '06/03/1996',
#   'Taille': '181',
#   'Poids': '100'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Handré POLLARD',
#   'Poste': 'Ouverture',
#   'Date de naissance': '11/03/1994',
#   'Taille': '189',
#   'Poids': '98'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Vincent GIUDICELLI',
#   'Poste': 'Talonneur',
#   'Date de naissance': '25/06/1997',
#   'Taille': '183',
#   'Poids': '100'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Guillaume MARCHAND',
#   'Poste': 'Talonneur',
#   'Date de naissance': '05/06/1998',
#   'Taille': '183',
#   'Poids': '100'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Liam GILL',
#   'Poste': '3ème ligne',
#   'Date de naissance': '08/06/1992',
#   'Taille': '184',
#   'Poids': '100'},
#  {'Equipe': 'Agen',
#   'Nom': 'Marc BARTHOMEUF',
#   'Poste': 'Talonneur',
#   'Date de naissance': '19/07/1991',
#   'Taille': '174',
#   'Poids': '100'},
#  {'Equipe': 'Agen',
#   'Nom': 'Julien JANÉ',
#   'Poste': 'Ailier',
#   'Date de naissance': '12/09/1989',
#   'Taille': '186',
#   'Poids': '100'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Peter BETHAM',
#   'Poste': 'Ailier',
#   'Date de naissance': '06/01/1989',
#   'Taille': '191',
#   'Poids': '98'},
#  {'Equipe': 'Paris',
#   'Nom': 'Rémi BONFILS',
#   'Poste': 'Talonneur',
#   'Date de naissance': '26/09/1988',
#   'Taille': '178',
#   'Poids': '101'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Camille CHAT',
#   'Poste': 'Talonneur',
#   'Date de naissance': '18/12/1995',
#   'Taille': '178',
#   'Poids': '101'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Clément MAYNADIER',
#   'Poste': 'Talonneur',
#   'Date de naissance': '11/10/1988',
#   'Taille': '187',
#   'Poids': '100'},
#  {'Equipe': 'Pau',
#   'Nom': 'Watisoni VOTU',
#   'Poste': 'Ailier',
#   'Date de naissance': '25/03/1985',
#   'Taille': '187',
#   'Poids': '100'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Filimo TAOFIFENUA',
#   'Poste': '3ème ligne',
#   'Date de naissance': '15/10/1993',
#   'Taille': '188',
#   'Poids': '100'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Xavier MIGNOT',
#   'Poste': 'Ailier',
#   'Date de naissance': '27/01/1994',
#   'Taille': '188',
#   'Poids': '100'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Kélian GALLETIER',
#   'Poste': '3ème ligne',
#   'Date de naissance': '18/03/1992',
#   'Taille': '188',
#   'Poids': '100'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Takeshi HINO',
#   'Poste': 'Talonneur',
#   'Date de naissance': '20/01/1990',
#   'Taille': '172',
#   'Poids': '100'},
#  {'Equipe': 'Paris',
#   'Nom': 'Sefa NAIVALU',
#   'Poste': 'Ailier',
#   'Date de naissance': '07/01/1992',
#   'Taille': '186',
#   'Poids': '101'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Fulgence OUEDRAOGO',
#   'Poste': '3ème ligne',
#   'Date de naissance': '21/07/1986',
#   'Taille': '191',
#   'Poids': '99'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Yohan BEHEREGARAY',
#   'Poste': 'Talonneur',
#   'Date de naissance': '29/05/1996',
#   'Taille': '180',
#   'Poids': '102'},
#  {'Equipe': 'Paris',
#   'Nom': 'Laurent PANIS',
#   'Poste': 'Talonneur',
#   'Date de naissance': '23/04/1993',
#   'Taille': '180',
#   'Poids': '102'},
#  {'Equipe': 'Brive',
#   'Nom': 'Saïd HIRÈCHE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '27/05/1985',
#   'Taille': '183',
#   'Poids': '102'},
#  {'Equipe': 'Paris',
#   'Nom': 'Gaël FICKOU',
#   'Poste': 'Centre',
#   'Date de naissance': '26/03/1994',
#   'Taille': '190',
#   'Poids': '100'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Pierre FOUYSSAC',
#   'Poste': 'Centre',
#   'Date de naissance': '17/03/1995',
#   'Taille': '190',
#   'Poids': '100'},
#  {'Equipe': 'Castres',
#   'Nom': 'Yann DAVID',
#   'Poste': 'Centre',
#   'Date de naissance': '15/04/1988',
#   'Taille': '185',
#   'Poids': '102'},
#  {'Equipe': 'Paris',
#   'Nom': 'Antoine BURBAN',
#   'Poste': '3ème ligne',
#   'Date de naissance': '22/07/1987',
#   'Taille': '189',
#   'Poids': '101'},
#  {'Equipe': 'Pau',
#   'Nom': 'Alexandre DUMOULIN',
#   'Poste': 'Centre',
#   'Date de naissance': '24/08/1989',
#   'Taille': '189',
#   'Poids': '101'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Baptiste HÉGUY',
#   'Poste': '3ème ligne',
#   'Date de naissance': '11/05/1998',
#   'Taille': '196',
#   'Poids': '97'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Levani BOTIA',
#   'Poste': 'Centre',
#   'Date de naissance': '14/03/1989',
#   'Taille': '182',
#   'Poids': '103'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Patricio FERNANDEZ',
#   'Poste': 'Ouverture',
#   'Date de naissance': '11/10/1994',
#   'Taille': '192',
#   'Poids': '100'},
#  {'Equipe': 'Pau',
#   'Nom': 'Antoine ERBANI',
#   'Poste': '3ème ligne',
#   'Date de naissance': '07/02/1990',
#   'Taille': '192',
#   'Poids': '100'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Benjamin COLLET',
#   'Poste': '3ème ligne',
#   'Date de naissance': '11/04/1989',
#   'Taille': '184',
#   'Poids': '103'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Semi RADRADRA',
#   'Poste': 'Centre',
#   'Date de naissance': '13/06/1992',
#   'Taille': '188',
#   'Poids': '102'},
#  {'Equipe': 'Pau',
#   'Nom': 'Atila SEPTAR',
#   'Poste': 'Centre',
#   'Date de naissance': '02/06/1996',
#   'Taille': '195',
#   'Poids': '99'},
#  {'Equipe': 'Brive',
#   'Nom': 'François DA ROS',
#   'Poste': 'Talonneur',
#   'Date de naissance': '29/09/1983',
#   'Taille': '179',
#   'Poids': '104'},
#  {'Equipe': 'Agen',
#   'Nom': 'Alban CONDUCHÉ',
#   'Poste': 'Centre',
#   'Date de naissance': '29/10/1996',
#   'Taille': '190',
#   'Poids': '102'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Ronan CHAMBORD',
#   'Poste': 'Talonneur',
#   'Date de naissance': '11/04/1994',
#   'Taille': '177',
#   'Poids': '104'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Alexandre FISCHER',
#   'Poste': '3ème ligne',
#   'Date de naissance': '19/01/1998',
#   'Taille': '188',
#   'Poids': '103'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Charlie NGATAI',
#   'Poste': 'Centre',
#   'Date de naissance': '17/08/1990',
#   'Taille': '188',
#   'Poids': '103'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Wenceslas LAURET',
#   'Poste': '3ème ligne',
#   'Date de naissance': '28/03/1989',
#   'Taille': '188',
#   'Poids': '103'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Zeno KIEFT',
#   'Poste': '3ème ligne',
#   'Date de naissance': '02/11/1991',
#   'Taille': '191',
#   'Poids': '102'},
#  {'Equipe': 'Paris',
#   'Nom': 'Sekou MACALOU',
#   'Poste': '3ème ligne',
#   'Date de naissance': '20/04/1995',
#   'Taille': '195',
#   'Poids': '100'},
#  {'Equipe': 'Brive',
#   'Nom': 'Peniami Nasali NARISIA',
#   'Poste': 'Talonneur',
#   'Date de naissance': '10/06/1997',
#   'Taille': '187',
#   'Poids': '104'},
#  {'Equipe': 'Clermont',
#   'Nom': 'George MOALA',
#   'Poste': 'Centre',
#   'Date de naissance': '05/11/1990',
#   'Taille': '187',
#   'Poids': '104'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Kévin GOURDON',
#   'Poste': '3ème ligne',
#   'Date de naissance': '23/01/1990',
#   'Taille': '190',
#   'Poids': '103'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Bastien SOURY',
#   'Poste': 'Talonneur',
#   'Date de naissance': '18/03/1995',
#   'Taille': '180',
#   'Poids': '105'},
#  {'Equipe': 'Agen',
#   'Nom': 'Clément MARTINEZ',
#   'Poste': 'Talonneur',
#   'Date de naissance': '14/03/1996',
#   'Taille': '181',
#   'Poids': '105'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Alexandre LAPANDRY',
#   'Poste': '3ème ligne',
#   'Date de naissance': '13/04/1989',
#   'Taille': '194',
#   'Poids': '101'},
#  {'Equipe': 'Castres',
#   'Nom': 'Kévin FIRMIN',
#   'Poste': 'Talonneur',
#   'Date de naissance': '20/04/1992',
#   'Taille': '183',
#   'Poids': '105'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Guilhem GUIRADO',
#   'Poste': 'Talonneur',
#   'Date de naissance': '17/06/1986',
#   'Taille': '183',
#   'Poids': '105'},
#  {'Equipe': 'Paris',
#   'Nom': 'Damien FITZPATRICK',
#   'Poste': 'Talonneur',
#   'Date de naissance': '08/06/1989',
#   'Taille': '183',
#   'Poids': '105'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Kévin LE GUEN',
#   'Poste': 'Talonneur',
#   'Date de naissance': '17/11/1990',
#   'Taille': '183',
#   'Poids': '105'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Tom DARLET',
#   'Poste': '3ème ligne',
#   'Date de naissance': '06/08/1996',
#   'Taille': '188',
#   'Poids': '104'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Apisai NAQALEVU',
#   'Poste': 'Centre',
#   'Date de naissance': '21/08/1989',
#   'Taille': '188',
#   'Poids': '104'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Rémi LAMERAT',
#   'Poste': 'Centre',
#   'Date de naissance': '14/01/1990',
#   'Taille': '184',
#   'Poids': '105'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Pierre BOURGARIT',
#   'Poste': 'Talonneur',
#   'Date de naissance': '12/09/1997',
#   'Taille': '184',
#   'Poids': '105'},
#  {'Equipe': 'Brive',
#   'Nom': 'Alex DUNBAR',
#   'Poste': 'Centre',
#   'Date de naissance': '23/04/1990',
#   'Taille': '191',
#   'Poids': '103'},
#  {'Equipe': 'Paris',
#   'Nom': 'Ryan CHAPUIS',
#   'Poste': '3ème ligne',
#   'Date de naissance': '12/12/1997',
#   'Taille': '189',
#   'Poids': '104'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Dylan CRETIN',
#   'Poste': '3ème ligne',
#   'Date de naissance': '04/05/1997',
#   'Taille': '195',
#   'Poids': '101'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Louis-Benoît MADAULE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '24/09/1988',
#   'Taille': '190',
#   'Poids': '104'},
#  {'Equipe': 'Paris',
#   'Nom': "Sione ANGA'AELANGI",
#   'Poste': 'Talonneur',
#   'Date de naissance': '07/11/1988',
#   'Taille': '180',
#   'Poids': '106'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Laurent DELBOULBÈS',
#   'Poste': 'Pilier',
#   'Date de naissance': '17/11/1986',
#   'Taille': '181',
#   'Poids': '106'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Timoci NAGUSA',
#   'Poste': 'Ailier',
#   'Date de naissance': '14/07/1987',
#   'Taille': '183',
#   'Poids': '106'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Mahamadou DIABY',
#   'Poste': '3ème ligne',
#   'Date de naissance': '15/08/1990',
#   'Taille': '188',
#   'Poids': '105'},
#  {'Equipe': 'Brive',
#   'Nom': 'Kitione KAMIKAMICA',
#   'Poste': '3ème ligne',
#   'Date de naissance': '27/04/1996',
#   'Taille': '188',
#   'Poids': '105'},
#  {'Equipe': 'Brive',
#   'Nom': 'Seva GALALA',
#   'Poste': 'Centre',
#   'Date de naissance': '29/01/1993',
#   'Taille': '188',
#   'Poids': '105'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Patrick SOBELA',
#   'Poste': '3ème ligne',
#   'Date de naissance': '12/08/1992',
#   'Taille': '188',
#   'Poids': '105'},
#  {'Equipe': 'Toulon',
#   'Nom': "Ben TE'O",
#   'Poste': 'Centre',
#   'Date de naissance': '27/01/1987',
#   'Taille': '188',
#   'Poids': '105'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Jaco VISAGIE',
#   'Poste': 'Talonneur',
#   'Date de naissance': '08/07/1992',
#   'Taille': '188',
#   'Poids': '105'},
#  {'Equipe': 'Agen',
#   'Nom': 'Vincent FARRÉ',
#   'Poste': '3ème ligne',
#   'Date de naissance': '06/06/1990',
#   'Taille': '193',
#   'Poids': '103'},
#  {'Equipe': 'Brive',
#   'Nom': 'Irakli TSKHADADZE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '01/08/1996',
#   'Taille': '191',
#   'Poids': '104'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Rémy GROSSO',
#   'Poste': 'Ailier',
#   'Date de naissance': '04/12/1988',
#   'Taille': '191',
#   'Poids': '104'},
#  {'Equipe': 'Agen',
#   'Nom': 'Morgan PHÉLIPPONNEAU',
#   'Poste': 'Pilier',
#   'Date de naissance': '05/09/1989',
#   'Taille': '185',
#   'Poids': '106'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Torsten VAN JAARSVELD',
#   'Poste': 'Talonneur',
#   'Date de naissance': '30/06/1987',
#   'Taille': '175',
#   'Poids': '106'},
#  {'Equipe': 'Castres',
#   'Nom': 'Jody JENNEKER',
#   'Poste': 'Talonneur',
#   'Date de naissance': '10/04/1984',
#   'Taille': '185',
#   'Poids': '106'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Béka GORGADZE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '08/02/1996',
#   'Taille': '189',
#   'Poids': '105'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Wiaan LIEBENBERG',
#   'Poste': '3ème ligne',
#   'Date de naissance': '31/08/1992',
#   'Taille': '189',
#   'Poids': '105'},
#  {'Equipe': 'Brive',
#   'Nom': 'Rico BULIRUARUA',
#   'Poste': 'Arrière',
#   'Date de naissance': '23/01/1997',
#   'Taille': '186',
#   'Poids': '106'},
#  {'Equipe': 'Pau',
#   'Nom': 'Matthieu UGENA',
#   'Poste': '3ème ligne',
#   'Date de naissance': '25/07/1995',
#   'Taille': '186',
#   'Poids': '106'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Antoine BATTUT',
#   'Poste': '3ème ligne',
#   'Date de naissance': '01/01/1984',
#   'Taille': '192',
#   'Poids': '104'},
#  {'Equipe': 'Pau',
#   'Nom': 'Clément FOURNIER',
#   'Poste': '3ème ligne',
#   'Date de naissance': '06/05/2000',
#   'Taille': '190',
#   'Poids': '105'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Masivesi DAKUWAQA',
#   'Poste': 'Ailier',
#   'Date de naissance': '14/02/1994',
#   'Taille': '190',
#   'Poids': '105'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Maxime DELONCA',
#   'Poste': 'Talonneur',
#   'Date de naissance': '29/04/1988',
#   'Taille': '180',
#   'Poids': '107'},
#  {'Equipe': 'Paris',
#   'Nom': 'Jonathan DANTY',
#   'Poste': 'Centre',
#   'Date de naissance': '07/10/1992',
#   'Taille': '181',
#   'Poids': '107'},
#  {'Equipe': 'Castres',
#   'Nom': 'Marc-Antoine RALLIER',
#   'Poste': 'Talonneur',
#   'Date de naissance': '02/12/1988',
#   'Taille': '182',
#   'Poids': '107'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Dorian LABORDE',
#   'Poste': 'Ailier',
#   'Date de naissance': '30/12/1996',
#   'Taille': '178',
#   'Poids': '107'},
#  {'Equipe': 'Brive',
#   'Nom': 'Joris JURAND',
#   'Poste': 'Arrière',
#   'Date de naissance': '11/11/1995',
#   'Taille': '188',
#   'Poids': '106'},
#  {'Equipe': 'Brive',
#   'Nom': 'Matthieu VOISIN',
#   'Poste': '3ème ligne',
#   'Date de naissance': '16/05/1996',
#   'Taille': '193',
#   'Poids': '104'},
#  {'Equipe': 'Paris',
#   'Nom': 'Waisea NAYACALEVU',
#   'Poste': 'Ailier',
#   'Date de naissance': '26/06/1990',
#   'Taille': '193',
#   'Poids': '104'},
#  {'Equipe': 'Castres',
#   'Nom': 'Paul SAUZARET',
#   'Poste': 'Talonneur',
#   'Date de naissance': '04/03/1997',
#   'Taille': '184',
#   'Poids': '107'},
#  {'Equipe': 'Castres',
#   'Nom': 'Wayan DE BENEDITTIS',
#   'Poste': 'Pilier',
#   'Date de naissance': '10/03/1999',
#   'Taille': '185',
#   'Poids': '107'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Giorgi BERIA',
#   'Poste': 'Pilier',
#   'Date de naissance': '11/11/1999',
#   'Taille': '175',
#   'Poids': '107'},
#  {'Equipe': 'Pau',
#   'Nom': 'Pierrick GUNTHER',
#   'Poste': '3ème ligne',
#   'Date de naissance': '16/10/1989',
#   'Taille': '190',
#   'Poids': '106'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Cameron WOKI',
#   'Poste': '3ème ligne',
#   'Date de naissance': '07/11/1998',
#   'Taille': '196',
#   'Poids': '103'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Clément LANEN',
#   'Poste': '2ème ligne',
#   'Date de naissance': '01/04/1998',
#   'Taille': '196',
#   'Poids': '103'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Julien PURICELLI',
#   'Poste': '3ème ligne',
#   'Date de naissance': '01/08/1981',
#   'Taille': '196',
#   'Poids': '103'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Mickaël IVALDI',
#   'Poste': 'Talonneur',
#   'Date de naissance': '20/02/1990',
#   'Taille': '181',
#   'Poids': '108'},
#  {'Equipe': 'Agen',
#   'Nom': 'Jordan PULETUA',
#   'Poste': 'Centre',
#   'Date de naissance': '28/02/1990',
#   'Taille': '193',
#   'Poids': '105'},
#  {'Equipe': 'Castres',
#   'Nom': 'Anthony JELONCH',
#   'Poste': '3ème ligne',
#   'Date de naissance': '28/07/1996',
#   'Taille': '193',
#   'Poids': '105'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Valentin SEILLÉ',
#   'Poste': 'Talonneur',
#   'Date de naissance': '07/04/1999',
#   'Taille': '182',
#   'Poids': '108'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Bryce HEEM ',
#   'Poste': 'Ailier',
#   'Date de naissance': '18/01/1989',
#   'Taille': '193',
#   'Poids': '105'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Fritz LEE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '29/08/1988',
#   'Taille': '188',
#   'Poids': '107'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Antonie CLAASSEN',
#   'Poste': '3ème ligne',
#   'Date de naissance': '20/10/1984',
#   'Taille': '191',
#   'Poids': '106'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Bruce DEVAUX',
#   'Poste': 'Pilier',
#   'Date de naissance': '14/11/1996',
#   'Taille': '183',
#   'Poids': '108'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Yoan TANGA-MANGENE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '29/11/1996',
#   'Taille': '185',
#   'Poids': '108'},
#  {'Equipe': 'Agen',
#   'Nom': 'Romain BRIATTE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '18/02/1993',
#   'Taille': '194',
#   'Poids': '105'},
# ...
#  {'Equipe': 'Pau',
#   'Nom': 'Baptiste PESENTI',
#   'Poste': '3ème ligne',
#   'Date de naissance': '03/07/1997',
#   'Taille': '195',
#   'Poids': '118'},
#  {'Equipe': 'Castres',
#   'Nom': 'Loïc JACQUET',
#   'Poste': '2ème ligne',
#   'Date de naissance': '31/03/1985',
#   'Taille': '198',
#   'Poids': '117'},
#  {'Equipe': 'Paris',
#   'Nom': 'Stéphane CLÉMENT',
#   'Poste': 'Pilier',
#   'Date de naissance': '03/09/1987',
#   'Taille': '183',
#   'Poids': '121'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Francisco GOMEZ KODELA',
#   'Poste': 'Pilier',
#   'Date de naissance': '03/07/1985',
#   'Taille': '184',
#   'Poids': '121'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Jaco VAN TONDER',
#   'Poste': '2ème ligne',
#   'Date de naissance': '03/03/1998',
#   'Taille': '197',
#   'Poids': '118'},
#  {'Equipe': 'Paris',
#   'Nom': 'Hugh PYLE',
#   'Poste': '2ème ligne',
#   'Date de naissance': '21/09/1988',
#   'Taille': '201',
#   'Poids': '116'},
#  {'Equipe': 'Agen',
#   'Nom': 'Laurence PEARCE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '03/12/1990',
#   'Taille': '192',
#   'Poids': '120'},
#  {'Equipe': 'Paris',
#   'Nom': 'Willem ALBERTS',
#   'Poste': '3ème ligne',
#   'Date de naissance': '11/05/1984',
#   'Taille': '192',
#   'Poids': '120'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Jannie DU PLESSIS',
#   'Poste': 'Pilier',
#   'Date de naissance': '16/11/1982',
#   'Taille': '188',
#   'Poids': '121'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Jandré MARAIS',
#   'Poste': '2ème ligne',
#   'Date de naissance': '14/06/1989',
#   'Taille': '198',
#   'Poids': '118'},
#  {'Equipe': 'Pau',
#   'Nom': 'Jale VATUBUA',
#   'Poste': 'Centre',
#   'Date de naissance': '30/08/1991',
#   'Taille': '189',
#   'Poids': '121'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Pieter Jan VAN LILL',
#   'Poste': '2ème ligne',
#   'Date de naissance': '04/12/1983',
#   'Taille': '193',
#   'Poids': '120'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Gillian GALAN',
#   'Poste': '3ème ligne',
#   'Date de naissance': '07/08/1991',
#   'Taille': '193',
#   'Poids': '120'},
#  {'Equipe': 'Brive',
#   'Nom': 'Mesake DOGE',
#   'Poste': 'Pilier',
#   'Date de naissance': '01/04/1993',
#   'Taille': '178',
#   'Poids': '122'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Swan REBBADJ',
#   'Poste': '2ème ligne',
#   'Date de naissance': '15/01/1995',
#   'Taille': '202',
#   'Poids': '116'},
#  {'Equipe': 'Agen',
#   'Nom': 'Anton PEIKRISHVILI',
#   'Poste': 'Pilier',
#   'Date de naissance': '18/09/1987',
#   'Taille': '183',
#   'Poids': '122'},
#  {'Equipe': 'Brive',
#   'Nom': 'Steevy CERQUEIRA',
#   'Poste': '3ème ligne',
#   'Date de naissance': '09/08/1993',
#   'Taille': '206',
#   'Poids': '114'},
#  {'Equipe': 'Brive',
#   'Nom': 'Jan UYS',
#   'Poste': '2ème ligne',
#   'Date de naissance': '03/01/1994',
#   'Taille': '195',
#   'Poids': '120'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Guillaume DUCAT',
#   'Poste': '2ème ligne',
#   'Date de naissance': '20/05/1996',
#   'Taille': '205',
#   'Poids': '115'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Paul JEDRASIAK',
#   'Poste': '2ème ligne',
#   'Date de naissance': '06/02/1993',
#   'Taille': '200',
#   'Poids': '118'},
#  {'Equipe': 'Brive',
#   'Nom': 'Mitch LEES',
#   'Poste': '2ème ligne',
#   'Date de naissance': '12/10/1988',
#   'Taille': '196',
#   'Poids': '120'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Peceli YATO',
#   'Poste': '3ème ligne',
#   'Date de naissance': '17/01/1993',
#   'Taille': '196',
#   'Poids': '120'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Mamuka GORGODZE',
#   'Poste': '2ème ligne',
#   'Date de naissance': '14/07/1984',
#   'Taille': '196',
#   'Poids': '120'},
#  {'Equipe': 'Agen',
#   'Nom': 'Kamaliele TUFELE',
#   'Poste': 'Pilier',
#   'Date de naissance': '11/10/1995',
#   'Taille': '182',
#   'Poids': '123'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Thomas JOLMÈS',
#   'Poste': '2ème ligne',
#   'Date de naissance': '08/10/1995',
#   'Taille': '204',
#   'Poids': '116'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Mathieu BASTAREAUD',
#   'Poste': 'Centre',
#   'Date de naissance': '17/09/1988',
#   'Taille': '183',
#   'Poids': '123'},
#  {'Equipe': 'Paris',
#   'Nom': 'Paul GABRILLAGUES',
#   'Poste': '2ème ligne',
#   'Date de naissance': '03/06/1993',
#   'Taille': '199',
#   'Poids': '119'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Dominic BIRD',
#   'Poste': '2ème ligne',
#   'Date de naissance': '09/04/1991',
#   'Taille': '206',
#   'Poids': '115'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Eben ETZEBETH',
#   'Poste': '2ème ligne',
#   'Date de naissance': '29/10/1991',
#   'Taille': '203',
#   'Poids': '117'},
#  {'Equipe': 'Pau',
#   'Nom': 'Dan MALAFOSSE',
#   'Poste': '2ème ligne',
#   'Date de naissance': '14/01/1992',
#   'Taille': '195',
#   'Poids': '121'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Etienne OOSTHUIZEN',
#   'Poste': '2ème ligne',
#   'Date de naissance': '22/12/1992',
#   'Taille': '198',
#   'Poids': '120'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Rynhardt ELSTADT',
#   'Poste': '3ème ligne',
#   'Date de naissance': '20/12/1989',
#   'Taille': '198',
#   'Poids': '120'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Arthur JOLY',
#   'Poste': 'Pilier',
#   'Date de naissance': '20/02/1988',
#   'Taille': '189',
#   'Poids': '123'},
#  {'Equipe': 'Pau',
#   'Nom': 'Fabrice METZ',
#   'Poste': '2ème ligne',
#   'Date de naissance': '23/01/1991',
#   'Taille': '196',
#   'Poids': '121'},
#  {'Equipe': 'Paris',
#   'Nom': 'Carlü SADIE',
#   'Poste': 'Pilier',
#   'Date de naissance': '07/03/1997',
#   'Taille': '180',
#   'Poids': '124'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Grégory FICHTEN',
#   'Poste': 'Pilier',
#   'Date de naissance': '13/08/1990',
#   'Taille': '183',
#   'Poids': '124'},
#  {'Equipe': 'Brive',
#   'Nom': 'Peet MARAIS',
#   'Poste': '2ème ligne',
#   'Date de naissance': '31/10/1990',
#   'Taille': '199',
#   'Poids': '120'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Rodrigue NETI',
#   'Poste': 'Pilier',
#   'Date de naissance': '26/04/1995',
#   'Taille': '185',
#   'Poids': '124'},
#  {'Equipe': 'Brive',
#   'Nom': 'Cody THOMAS',
#   'Poste': 'Pilier',
#   'Date de naissance': '01/03/1996',
#   'Taille': '186',
#   'Poids': '124'},
#  {'Equipe': 'Paris',
#   'Nom': 'Yoann MAESTRI',
#   'Poste': '2ème ligne',
#   'Date de naissance': '14/01/1988',
#   'Taille': '202',
#   'Poids': '119'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Sergio PARISSE',
#   'Poste': '3ème ligne',
#   'Date de naissance': '12/09/1983',
#   'Taille': '196',
#   'Poids': '122'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Viliamu AFATIA',
#   'Poste': 'Pilier',
#   'Date de naissance': '24/05/1990',
#   'Taille': '189',
#   'Poids': '124'},
#  {'Equipe': 'Bayonne',
#   'Nom': "Toma'Akino TAUFA",
#   'Poste': 'Pilier',
#   'Date de naissance': '09/03/1995',
#   'Taille': '180',
#   'Poids': '125'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Loni UHILA',
#   'Poste': 'Pilier',
#   'Date de naissance': '07/04/1989',
#   'Taille': '182',
#   'Poids': '125'},
#  {'Equipe': 'Agen',
#   'Nom': 'Pierce PHILLIPS',
#   'Poste': '2ème ligne',
#   'Date de naissance': '06/10/1992',
#   'Taille': '203',
#   'Poids': '119'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Thierry PAÏVA',
#   'Poste': 'Pilier',
#   'Date de naissance': '19/11/1995',
#   'Taille': '184',
#   'Poids': '125'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Ramiro HERRERA',
#   'Poste': 'Pilier',
#   'Date de naissance': '14/02/1989',
#   'Taille': '194',
#   'Poids': '123'},
#  {'Equipe': 'Pau',
#   'Nom': "Siegfried FISI'IHOI",
#   'Poste': 'Pilier',
#   'Date de naissance': '06/08/1987',
#   'Taille': '184',
#   'Poids': '125'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Lopeti TIMANI',
#   'Poste': '3ème ligne',
#   'Date de naissance': '28/09/1990',
#   'Taille': '193',
#   'Poids': '124'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Sébastien VAHAAMAHINA',
#   'Poste': '2ème ligne',
#   'Date de naissance': '21/10/1991',
#   'Taille': '203',
#   'Poids': '120'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Sitaleki TIMANI',
#   'Poste': '2ème ligne',
#   'Date de naissance': '19/09/1986',
#   'Taille': '203',
#   'Poids': '120'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Ugo BONIFACE',
#   'Poste': 'Pilier',
#   'Date de naissance': '21/07/1998',
#   'Taille': '190',
#   'Poids': '125'},
#  {'Equipe': 'Castres',
#   'Nom': "Paea FA'ANUNU",
#   'Poste': 'Pilier',
#   'Date de naissance': '04/11/1988',
#   'Taille': '191',
#   'Poids': '125'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Bastien CHALUREAU',
#   'Poste': '2ème ligne',
#   'Date de naissance': '13/02/1992',
#   'Taille': '202',
#   'Poids': '121'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Alexandre FLANQUART',
#   'Poste': '2ème ligne',
#   'Date de naissance': '09/10/1989',
#   'Taille': '204',
#   'Poids': '120'},
#  {'Equipe': 'Pau',
#   'Nom': 'Julien DELANNOY',
#   'Poste': '2ème ligne',
#   'Date de naissance': '15/06/1995',
#   'Taille': '198',
#   'Poids': '123'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Mohamed HAOUAS',
#   'Poste': 'Pilier',
#   'Date de naissance': '09/03/1994',
#   'Taille': '185',
#   'Poids': '127'},
#  {'Equipe': 'Castres',
#   'Nom': 'Victor MOREAUX',
#   'Poste': '2ème ligne',
#   'Date de naissance': '19/09/1993',
#   'Taille': '200',
#   'Poids': '123'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Jacques DU PLESSIS',
#   'Poste': '2ème ligne',
#   'Date de naissance': '12/08/1993',
#   'Taille': '201',
#   'Poids': '123'},
#  {'Equipe': 'Pau',
#   'Nom': 'Lucas POINTUD',
#   'Poste': 'Pilier',
#   'Date de naissance': '18/01/1988',
#   'Taille': '189',
#   'Poids': '127'},
#  {'Equipe': 'Paris',
#   'Nom': 'Paul ALO-EMILE',
#   'Poste': 'Pilier',
#   'Date de naissance': '22/12/1991',
#   'Taille': '180',
#   'Poids': '128'},
#  {'Equipe': 'Pau',
#   'Nom': 'Mohamed BOUGHANMI',
#   'Poste': 'Pilier',
#   'Date de naissance': '27/10/1991',
#   'Taille': '194',
#   'Poids': '126'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Sila PUAFISI',
#   'Poste': 'Pilier',
#   'Date de naissance': '15/04/1988',
#   'Taille': '183',
#   'Poids': '128'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Charlie FAUMUINA',
#   'Poste': 'Pilier',
#   'Date de naissance': '24/12/1986',
#   'Taille': '184',
#   'Poids': '128'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Kane DOUGLAS',
#   'Poste': '2ème ligne',
#   'Date de naissance': '01/06/1989',
#   'Taille': '202',
#   'Poids': '123'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Adam JAULHAC',
#   'Poste': '2ème ligne',
#   'Date de naissance': '31/01/1988',
#   'Taille': '198',
#   'Poids': '125'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Evrard Dion OULAI',
#   'Poste': '2ème ligne',
#   'Date de naissance': '22/06/1993',
#   'Taille': '198',
#   'Poids': '125'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Rory ARNOLD',
#   'Poste': '2ème ligne',
#   'Date de naissance': '01/07/1990',
#   'Taille': '208',
#   'Poids': '120'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Mat LUAMANU',
#   'Poste': '3ème ligne',
#   'Date de naissance': '04/03/1988',
#   'Taille': '193',
#   'Poids': '127'},
#  {'Equipe': 'Brive',
#   'Nom': "So'otala FA'ASO'O",
#   'Poste': '3ème ligne',
#   'Date de naissance': '02/10/1994',
#   'Taille': '194',
#   'Poids': '127'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Leone NAKARAWA',
#   'Poste': '2ème ligne',
#   'Date de naissance': '04/02/1988',
#   'Taille': '200',
#   'Poids': '125'},
#  {'Equipe': 'Lyon',
#   'Nom': 'Hendrik ROODT',
#   'Poste': '2ème ligne',
#   'Date de naissance': '06/11/1987',
#   'Taille': '198',
#   'Poids': '126'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Jon ZABALA',
#   'Poste': 'Pilier',
#   'Date de naissance': '26/11/1996',
#   'Taille': '192',
#   'Poids': '128'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Sébastien TAOFIFENUA',
#   'Poste': 'Pilier',
#   'Date de naissance': '21/03/1992',
#   'Taille': '178',
#   'Poids': '130'},
#  {'Equipe': 'Brive',
#   'Nom': 'James JOHNSTON',
#   'Poste': 'Pilier',
#   'Date de naissance': '06/03/1986',
#   'Taille': '191',
#   'Poids': '129'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Iosefa TEKORI',
#   'Poste': '2ème ligne',
#   'Date de naissance': '17/12/1983',
#   'Taille': '198',
#   'Poids': '127'},
#  {'Equipe': 'Castres',
#   'Nom': 'Karena WIHONGI',
#   'Poste': 'Pilier',
#   'Date de naissance': '29/09/1979',
#   'Taille': '186',
#   'Poids': '130'},
#  {'Equipe': 'Clermont',
#   'Nom': 'George MERRICK',
#   'Poste': '2ème ligne',
#   'Date de naissance': '04/10/1992',
#   'Taille': '201',
#   'Poids': '126'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Vincent PELO',
#   'Poste': 'Pilier',
#   'Date de naissance': '22/04/1988',
#   'Taille': '187',
#   'Poids': '130'},
#  {'Equipe': 'Paris',
#   'Nom': 'Luke TAGI',
#   'Poste': 'Pilier',
#   'Date de naissance': '23/06/1997',
#   'Taille': '187',
#   'Poids': '130'},
#  {'Equipe': 'Pau',
#   'Nom': 'Geoffrey MOÏSE',
#   'Poste': 'Pilier',
#   'Date de naissance': '20/08/1991',
#   'Taille': '187',
#   'Poids': '130'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Census JOHNSTON',
#   'Poste': 'Pilier',
#   'Date de naissance': '06/05/1981',
#   'Taille': '189',
#   'Poids': '130'},
#  {'Equipe': 'Clermont',
#   'Nom': 'Duane AHOLELEI',
#   'Poste': 'Pilier',
#   'Date de naissance': '16/02/1989',
#   'Taille': '189',
#   'Poids': '130'},
#  {'Equipe': 'Bordeaux',
#   'Nom': 'Masalosalo TUTAIA',
#   'Poste': '2ème ligne',
#   'Date de naissance': '05/06/1984',
#   'Taille': '204',
#   'Poids': '125'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Corentin VERNET',
#   'Poste': '2ème ligne',
#   'Date de naissance': '27/09/1996',
#   'Taille': '200',
#   'Poids': '127'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Romain TAOFIFENUA',
#   'Poste': '2ème ligne',
#   'Date de naissance': '14/09/1990',
#   'Taille': '200',
#   'Poids': '127'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Richie GRAY',
#   'Poste': '2ème ligne',
#   'Date de naissance': '24/08/1989',
#   'Taille': '206',
#   'Poids': '125'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Nemani NADOLO',
#   'Poste': 'Ailier',
#   'Date de naissance': '31/01/1988',
#   'Taille': '194',
#   'Poids': '130'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Konstantine MIKAUTADZE',
#   'Poste': '2ème ligne',
#   'Date de naissance': '01/07/1991',
#   'Taille': '200',
#   'Poids': '128'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Paulo TAFILI',
#   'Poste': 'Pilier',
#   'Date de naissance': '15/02/1996',
#   'Taille': '183',
#   'Poids': '132'},
#  {'Equipe': 'Castres',
#   'Nom': 'Matt TIERNEY',
#   'Poste': 'Pilier',
#   'Date de naissance': '04/07/1996',
#   'Taille': '191',
#   'Poids': '132'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Paul WILLEMSE',
#   'Poste': '2ème ligne',
#   'Date de naissance': '13/11/1992',
#   'Taille': '201',
#   'Poids': '129'},
#  {'Equipe': 'Toulon',
#   'Nom': 'Wilco LOUW',
#   'Poste': 'Pilier',
#   'Date de naissance': '20/07/1994',
#   'Taille': '185',
#   'Poids': '133'},
#  {'Equipe': 'Castres',
#   'Nom': 'Wilfrid HOUNKPATIN',
#   'Poste': 'Pilier',
#   'Date de naissance': '29/07/1991',
#   'Taille': '192',
#   'Poids': '132'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Daniel BRENNAN',
#   'Poste': 'Pilier',
#   'Date de naissance': '23/09/1998',
#   'Taille': '192',
#   'Poids': '132'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Georges-Henri COLOMBE',
#   'Poste': 'Pilier',
#   'Date de naissance': '09/04/1998',
#   'Taille': '193',
#   'Poids': '133'},
#  {'Equipe': 'Toulouse',
#   'Nom': 'Richie ARNOLD',
#   'Poste': '2ème ligne',
#   'Date de naissance': '01/07/1990',
#   'Taille': '208',
#   'Poids': '127'},
#  {'Equipe': 'Agen',
#   'Nom': 'Mickaël DE MARCO',
#   'Poste': '2ème ligne',
#   'Date de naissance': '22/04/1989',
#   'Taille': '195',
#   'Poids': '134'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Jone QOVU',
#   'Poste': '2ème ligne',
#   'Date de naissance': '26/07/1985',
#   'Taille': '197',
#   'Poids': '134'},
#  {'Equipe': 'Montpellier',
#   'Nom': 'Antoine GUILLAMON',
#   'Poste': 'Pilier',
#   'Date de naissance': '04/06/1991',
#   'Taille': '192',
#   'Poids': '136'},
#  {'Equipe': 'Castres',
#   'Nom': 'Tapu FALATEA',
#   'Poste': 'Pilier',
#   'Date de naissance': '12/12/1988',
#   'Taille': '187',
#   'Poids': '137'},
#  {'Equipe': 'Paris',
#   'Nom': 'Christopher VAOTOA',
#   'Poste': 'Pilier',
#   'Date de naissance': '16/11/1996',
#   'Taille': '185',
#   'Poids': '138'},
#  {'Equipe': 'Toulon',
#   'Nom': "Brian ALAINU'UESE",
#   'Poste': '2ème ligne',
#   'Date de naissance': '19/03/1994',
#   'Taille': '202',
#   'Poids': '135'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Ben TAMEIFUNA',
#   'Poste': 'Pilier',
#   'Date de naissance': '30/08/1991',
#   'Taille': '182',
#   'Poids': '140'},
#  {'Equipe': 'Racing92',
#   'Nom': 'Ali OZ',
#   'Poste': 'Pilier',
#   'Date de naissance': '28/05/1995',
#   'Taille': '193',
#   'Poids': '140'},
#  {'Equipe': 'Bayonne',
#   'Nom': 'Edwin MAKA',
#   'Poste': '2ème ligne',
#   'Date de naissance': '25/01/1993',
#   'Taille': '196',
#   'Poids': '140'},
#  {'Equipe': 'Pau',
#   'Nom': 'Malik HAMADACHE',
#   'Poste': 'Pilier',
#   'Date de naissance': '17/10/1988',
#   'Taille': '193',
#   'Poids': '141'},
#  {'Equipe': 'La Rochelle',
#   'Nom': 'Uini ATONIO',
#   'Poste': 'Pilier',
#   'Date de naissance': '26/03/1990',
#   'Taille': '196',
#   'Poids': '152'}]
